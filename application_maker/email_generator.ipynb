# %%
from pathlib import Path
import os
import sys
sys.path.append(sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("utils")))))
from utils.toms_python_utilities import emailGenerator, send_email, google_search, tomide_bs4_make_soup, create_csv_file, mail_checker
from utils.networking_manager import connection_unknown_person, get_cover_letter_cv, vc_fund_template, tomide_adeoye_contact, person_frontend_engineer_application, person_python_engineer_application, verbose_tomide_adeoye_contact

# %%
def getPerson(target_company , role, name):
    try:
        google_response = google_search("site:linkedin.com/in intitle:"+role+" "+ target_company['company_name'])
        if google_response == None:
            return 

        target_linkedin_person = google_response[0]
        linkedinPersonName = target_linkedin_person['title'].split(" - ")[0].split(" ") # ['John', 'Doe']
        if len(linkedinPersonName) == 2:
            first_name, last_name = linkedinPersonName[0], linkedinPersonName[1]
        else:
            first_name=  linkedinPersonName[0] 
            # compare name2 and name3 to see which is the last name
            if len(linkedinPersonName[1]) > len(linkedinPersonName[2]):
                last_name = linkedinPersonName[1]
            else:
                last_name = linkedinPersonName[2]



        first_name, last_name = linkedinPersonName[0], linkedinPersonName[1] # John Doe

        print(linkedinPersonName, role, target_linkedin_person['link'], target_linkedin_person['snippet'])

        if name['first_name'] != None:
            first_name = name['first_name']
        if name['last_name'] != None:
            last_name = name['last_name']

        valid_email = emailGenerator(first_name, last_name, target_company['company_domain']) # generates a list of possible email addresses:
        print({
                "name": linkedinPersonName,
                "role": role,
                "company_name": target_company['company_name'],
                "company_domain": target_company['company_domain'],
                "linkedin_url": target_linkedin_person['link'],
                "person_snippet": target_linkedin_person['snippet'],
                "company_snippet": target_company['snippet'],

                "email": valid_email
            }) 

        return {
                "name": linkedinPersonName,
                "role": role,
                "company_name": target_company['company_name'],
                "company_domain": target_company['company_domain'],
                "linkedin_url": target_linkedin_person['link'],
                "person_snippet": target_linkedin_person['snippet'],
                "company_snippet": target_company['snippet'],
                "email": valid_email
            }
            
    except Exception as e:
        print(e)
        pass

# %%
back_up_list
# Out:
# [[{'name': ['Veronica', 'Conforme'],
#    'role': 'ceo',
#    'company_name': 'Manta Network',
#    'company_domain': 'www.manta.network',
#    'linkedin_url': 'https://www.linkedin.com/in/veronica-conforme-399477b',
#    'person_snippet': "View Veronica Conforme's profile on LinkedIn, the world's largest professional community. Veronica has 6 jobs listed on their profile.",
#    'company_snippet': 'Using Polkadot cross-consensus messaging (XCM) mechanism, Manta Network is able to communicate with other layer-1 decentralized networks within the Polkadot\xa0...',
#    'email': ['Veronica@manta.network',
#     'Conforme@manta.network',
#     'VeronicaConforme@manta.network',
#     'ConformeVeronica@manta.network',
#     'Veronica.Conforme@manta.network',
#     'Conforme.Veronica@manta.network',
#     'VeronicaC@manta.network',
#     'CVeronica@manta.network',
#     'VConforme@manta.network',
#     'ConformeV@manta.network',
#     'Veronica.C@manta.network',
# ...

# %%
target_company_list = ["Insight Partners", "QED Investors", "Harlem Capital", ]
target_company_list = ["Manta Network"]
# target_company_list = ["Evolve Ventures and Foundation", "Ridge Ventures", "Mavik Ventures", "Venture Platform", "IDL Ventures", "Foundation Ventures", "Red ventures", "Outlier Ventures", "BlueYard Capital", "Fabric Ventures", "Semantic Ventures", "Maven11", "Signature Ventures", "Blockwall Capital", "Vito ventures", "Seed+speed"]
target_company_list = ['2150 venture', '7Percent venture', 'Accel Partners venture', 'Amadeus venture', 'Anthemis venture', 'Ascension venture', 'Balderton Capital venture', 'BGF Growth Capital venture', 'Connect Ventures', 'Crane ventures']


back_up_list = []

target_company_list =['ipayBTC', 'Chipper Cash', 'Canonical']

def email_aggregator(company_name):
    try:
        google_response = google_search(company_name + " company")
        if google_response == None:
            return 

        companies= [{
                "company_name": company_name,
                "title": company['title'],
                "link": company['link'],
                "snippet": company['snippet'],
                "company_domain": company['displayLink'],
            } for company in google_response]

        all_company_details =  [detail['snippet'] for detail in companies] 

        companies = [company for company in companies if "linkedin" not in company['link'] and "crunchbase" not in company['link'] and "pitchbook" not in company['link']]

        target_company = companies[0]
        target_company['details'] = all_company_details

        name = {"first_name": None,  "last_name": None}
        response = [getPerson(target_company, role,  name) for role in ['ceo', 'founder', 'recruiter', 'partner']] # exceute function getPerson for each role in the list
        back_up_list.append(response)
        return response

    except Exception as e:
        print(e)
        pass

draft_list = [email_aggregator(company) for company in target_company_list]


draft_list = [item for sublist in back_up_list for item in sublist if item != None ]
application_list = []
all_names =  []
all_linkedins = [item['linkedin_url'] for item in draft_list]
# [webbrowser.open(link) for link in all_linkedins]

# for item in draft_list:
#     name = item['name'][0]
#     if name not in all_names and item['email'] != []:
#         application_list.append(item)
#         all_names.append(name)
# application_list


# for person in application_list:
#     try:
#         make_vc_application1(person)
#     except Exception as e:
#         print(e)
#         print(person['email'], "Failed to apply")
# Out:
# 'error'
# ['Uchenna', 'Mba'] founder https://ng.linkedin.com/in/urchymanny IpayBTC. Nov 2020 - Feb 2021. I used Ruby to build a cryptocurrency backend application and an API which the mobile app fed on. A platform fully backed by ...
# Generating email list for Uchenna Mba
# {'name': ['Uchenna', 'Mba'], 'role': 'founder', 'company_name': 'ipayBTC', 'company_domain': 'ipaybtc.app', 'linkedin_url': 'https://ng.linkedin.com/in/urchymanny', 'person_snippet': 'IpayBTC. Nov 2020 - Feb 2021. I used Ruby to build a cryptocurrency backend application and an API which the mobile app fed on. A platform fully backed by\xa0...', 'company_snippet': 'Your Bitcoin Payment Platform Defining value ,one Bitcoin user at a time A customer driven company with a laser focused goal to contribute our iron rods to\xa0...', 'email': []}
# 'error'
# 'error'
# ...

# %%
application_list
# Out:
# [{'name': ['Jeff', 'Burton'],
#   'role': 'ceo',
#   'company_name': '2150 venture',
#   'company_domain': 'www.2150.vc',
#   'linkedin_url': 'https://www.linkedin.com/in/jeffburtonofficial',
#   'person_snippet': 'Executive Director. SkyDeck | Berkeley. Jul 2012 - Dec 2014 2 years 6 months. 2150 Shattuck Ave, Berkeley, CA 94704. Club Salviatino Graphic\xa0...',
#   'company_snippet': 'A sustainable approach to venture. Led and backed by serious players in the Urban Stack, our team combines institutional strength and entrepreneurial spirit\xa0...',
#   'email': ['JB@2150.vc']},
#  {'name': ['Christian', 'Hernandez', 'Gallardo'],
#   'role': 'founder',
#   'company_name': '2150 venture',
#   'company_domain': 'www.2150.vc',
#   'linkedin_url': 'https://uk.linkedin.com/in/christianhern',
#   'person_snippet': "2150 is a venture capital firm investing in technology companies that seek to sustainably reimagine and reshape the urban environment. 2150's investment\xa0...",
# ...

# %%
# Out:
# [{'name': ['Ophelia', 'Brown'],
#   'role': 'founder',
#   'company_name': 'Blossom Capital',
#   'company_domain': 'www.blossomcap.com',
#   'linkedin_url': 'https://uk.linkedin.com/in/opheliabrown',
#   'person_snippet': "View Ophelia Brown's profile on LinkedIn, the world's largest professional community. Ophelia has 27 jobs listed on their profile. See the complete profile\xa0...",
#   'company_snippet': '"We have chosen Blossom for our A round because they truly understood our needs and what it meant to build a high growth company. In venture capital it is\xa0...',
#   'email': ['Ophelia@blossomcap.com',
#    'OpheliaBrown@blossomcap.com',
#    'OpheliaB@blossomcap.com',
#    'OBrown@blossomcap.com']},
#  {'name': ['Imran', 'Ghory'],
#   'role': 'partner',
#   'company_name': 'Blossom Capital',
#   'company_domain': 'www.blossomcap.com',
#   'linkedin_url': 'https://uk.linkedin.com/in/ighory',
# ...

# %%
mantra = [{'name': ['Veronica', 'Conforme'],
  'role': 'ceo',
  'company_name': 'Manta Network',
  'company_domain': 'www.manta.network',
  'linkedin_url': 'https://www.linkedin.com/in/veronica-conforme-399477b',
  'person_snippet': "View Veronica Conforme's profile on LinkedIn, the world's largest professional community. Veronica has 6 jobs listed on their profile.",
  'company_snippet': 'Using Polkadot cross-consensus messaging (XCM) mechanism, Manta Network is able to communicate with other layer-1 decentralized networks within the Polkadot\xa0...',
  'email': ['Veronica@manta.network',
   'Conforme@manta.network',
   'VeronicaConforme@manta.network',
   'ConformeVeronica@manta.network',
   'Veronica.Conforme@manta.network',
   'Conforme.Veronica@manta.network',
   'VeronicaC@manta.network',
   'CVeronica@manta.network',
   'VConforme@manta.network',
   'ConformeV@manta.network',
   'Veronica.C@manta.network',
   'C.Veronica@manta.network',
   'V.Conforme@manta.network',
   'Conforme.V@manta.network',
   'VC@manta.network',
   'CV@manta.network',
   'C.V@manta.network',
   'V.C@manta.network']},
 {'name': ['Victor', 'Ji,', 'CPA'],
  'role': 'founder',
  'company_name': 'Manta Network',
  'company_domain': 'www.manta.network',
  'linkedin_url': 'https://www.linkedin.com/in/victor-ji-cpa-37688a5b',
  'person_snippet': 'Cofounder of Manta Network. Binance Evangelist. MiraclePlus (former YC China) Fellow. Advisor to Unifi Protocol. Columnist of Chainnews, 8Btc, Mars finance\xa0...',
  'company_snippet': 'Using Polkadot cross-consensus messaging (XCM) mechanism, Manta Network is able to communicate with other layer-1 decentralized networks within the Polkadot\xa0...',
  'email': ['Victor@manta.network',
   'VictorJ@manta.network',
   'JVictor@manta.network',
   'Victor.J@manta.network',
   'J.Victor@manta.network',
   'VJ@manta.network',
   'JV@manta.network',
   'J.V@manta.network',
   'V.J@manta.network']},
 {'name': ['Steve', 'McLean,', 'Recruiter'],
  'role': 'recruiter',
  'company_name': 'Manta Network',
  'company_domain': 'www.manta.network',
  'linkedin_url': 'https://www.linkedin.com/in/stevenmclean',
  'person_snippet': "Director, HVAC / Refrigeration Recruitment, Manta Resources, Inc. (317) 773-4323 ... Manta Resources is part of MRI Network the World's largest Contingency\xa0...",
  'company_snippet': 'Using Polkadot cross-consensus messaging (XCM) mechanism, Manta Network is able to communicate with other layer-1 decentralized networks within the Polkadot\xa0...',
  'email': ['Steve@manta.network',
   'SteveM@manta.network',
   'MSteve@manta.network',
   'Steve.M@manta.network',
   'M.Steve@manta.network',
   'SM@manta.network',
   'MS@manta.network',
   'M.S@manta.network',
   'S.M@manta.network']},
 {'name': ['Jim', 'Smith'],
  'role': 'partner',
  'company_name': 'Manta Network',
  'company_domain': 'www.manta.network',
  'linkedin_url': 'https://www.linkedin.com/in/jim-smith-06070069',
  'person_snippet': 'As Managing Partner for The Enrollment Network, I am responsible for recruiting and developing a successful team of professionals who can meet the benefits\xa0...',
  'company_snippet': 'Using Polkadot cross-consensus messaging (XCM) mechanism, Manta Network is able to communicate with other layer-1 decentralized networks within the Polkadot\xa0...',
  'email': ['Jim@manta.network',
   'Smith@manta.network',
   'JimSmith@manta.network',
   'SmithJim@manta.network',
   'Jim.Smith@manta.network',
   'Smith.Jim@manta.network',
   'JimS@manta.network',
   'SJim@manta.network',
   'JSmith@manta.network',
   'SmithJ@manta.network',
   'Jim.S@manta.network',
   'S.Jim@manta.network',
   'J.Smith@manta.network',
   'Smith.J@manta.network',
   'JS@manta.network',
   'SJ@manta.network',
   'S.J@manta.network',
   'J.S@manta.network']}]

# %%
supreme_list = [
 {'name': 'Austin King',
  'job_title': 'founder',
  'company_name': 'Rift Finance',
  'company_domain': 'rift.finance',
  'linkedin_url': 'https://www.linkedin.com/in/austin-king-61a9b8b9',
  'linkedin_snippet': "Studied computer science at Harvard, sold my first company to Ripple, now I'm building at Rift Finance. | Learn more about Austin King's work experience,\xa0...",
  'email': ['Austin@rift.finance',
   'King@rift.finance',
   'AustinKing@rift.finance',
   'KingAustin@rift.finance',
   'Austin.King@rift.finance',
   'King.Austin@rift.finance',
   'AustinK@rift.finance',
   'KAustin@rift.finance',
   'AKing@rift.finance',
   'KingA@rift.finance',
   'Austin.K@rift.finance',
   'K.Austin@rift.finance',
   'A.King@rift.finance',
   'King.A@rift.finance',
   'AK@rift.finance',
   'KA@rift.finance',
   'K.A@rift.finance',
   'A.K@rift.finance']},
 {'name': 'Allan M. Thiga',
  'job_title': 'coo',
  'company_name': 'Rift Finance',
  'company_domain': 'rift.finance',
  'linkedin_url': 'https://ke.linkedin.com/in/allan-m-thiga-17574512',
  'linkedin_snippet': 'Finance | Operations | Entrepreneur | Advisor ... Rift Valley Apothecary specializes in the production of essential oils and tinctures.',
  'email': ['Allan@rift.finance',
   'M.@rift.finance',
   'AllanM.@rift.finance',
   'M.Allan@rift.finance',
   'Allan.M.@rift.finance',
   'AllanM@rift.finance',
   'MAllan@rift.finance',
   'AM.@rift.finance',
   'M.A@rift.finance',
   'Allan.M@rift.finance',
   'M.Allan@rift.finance',
   'A.M.@rift.finance',
   'AM@rift.finance',
   'MA@rift.finance',
   'M.A@rift.finance',
   'A.M@rift.finance']},
 {'name': 'Jesse Hunter',
  'job_title': 'recruiter',
  'company_name': 'Rift Finance',
  'company_domain': 'rift.finance',
  'linkedin_url': 'https://www.linkedin.com/in/jesse-hunter-923434129',
  'linkedin_snippet': 'Check out our open roles: League of Legends https://www.riotgames.com/en/work-with-us/jobs#product=League%20of%20Legends&office=884 Wild Rift:\xa0...',
  'email': ['Jesse@rift.finance',
   'Hunter@rift.finance',
   'JesseHunter@rift.finance',
   'HunterJesse@rift.finance',
   'Jesse.Hunter@rift.finance',
   'Hunter.Jesse@rift.finance',
   'JesseH@rift.finance',
   'HJesse@rift.finance',
   'JHunter@rift.finance',
   'HunterJ@rift.finance',
   'Jesse.H@rift.finance',
   'H.Jesse@rift.finance',
   'J.Hunter@rift.finance',
   'Hunter.J@rift.finance',
   'JH@rift.finance',
   'HJ@rift.finance',
   'H.J@rift.finance',
   'J.H@rift.finance']},
 {'name': 'Sewu-Steve T.',
  'job_title': 'partner',
  'company_name': 'Rift Finance',
  'company_domain': 'rift.finance',
  'linkedin_url': 'https://ke.linkedin.com/in/stevetawia',
  'linkedin_snippet': 'Partner@Jaza Rift Ventures | health tech, medtech, digital health | Better ... is facilitated by the Collaborative for Frontier Finance (CFF)to advance the\xa0...',
  'email': ['Sewu-Steve@rift.finance',
   'T.@rift.finance',
   'Sewu-SteveT.@rift.finance',
   'T.Sewu-Steve@rift.finance',
   'Sewu-Steve.T.@rift.finance',
   'Sewu-SteveT@rift.finance',
   'TSewu-Steve@rift.finance',
   'ST.@rift.finance',
   'T.S@rift.finance',
   'Sewu-Steve.T@rift.finance',
   'T.Sewu-Steve@rift.finance',
   'S.T.@rift.finance',
   'ST@rift.finance',
   'TS@rift.finance',
   'T.S@rift.finance',
   'S.T@rift.finance']},
 {'Rift Finance': [{'name': 'Walden Yan',
    'job_title': 'ceo',
    'company_name': 'Rift Finance',
    'company_domain': 'rift.finance',
    'linkedin_url': 'https://www.linkedin.com/in/waldenyan',
    'linkedin_snippet': 'Rift Finance. Nov 2021 - Jan 2022 3 months. Manhattan, New York, United States. Writing core smart contracts for financial securities across multiple chains\xa0...',
    'email': ['Walden@rift.finance',
     'Yan@rift.finance',
     'WaldenYan@rift.finance',
     'YanWalden@rift.finance',
     'Walden.Yan@rift.finance',
     'Yan.Walden@rift.finance',
     'WaldenY@rift.finance',
     'YWalden@rift.finance',
     'WYan@rift.finance',
     'YanW@rift.finance',
     'Walden.Y@rift.finance',
     'Y.Walden@rift.finance',
     'W.Yan@rift.finance',
     'Yan.W@rift.finance',
     'WY@rift.finance',
     'YW@rift.finance',
     'Y.W@rift.finance',
     'W.Y@rift.finance']},
   {'name': 'Austin King',
    'job_title': 'founder',
    'company_name': 'Rift Finance',
    'company_domain': 'rift.finance',
    'linkedin_url': 'https://www.linkedin.com/in/austin-king-61a9b8b9',
    'linkedin_snippet': "Studied computer science at Harvard, sold my first company to Ripple, now I'm building at Rift Finance. | Learn more about Austin King's work experience,\xa0...",
    'email': ['Austin@rift.finance',
     'King@rift.finance',
     'AustinKing@rift.finance',
     'KingAustin@rift.finance',
     'Austin.King@rift.finance',
     'King.Austin@rift.finance',
     'AustinK@rift.finance',
     'KAustin@rift.finance',
     'AKing@rift.finance',
     'KingA@rift.finance',
     'Austin.K@rift.finance',
     'K.Austin@rift.finance',
     'A.King@rift.finance',
     'King.A@rift.finance',
     'AK@rift.finance',
     'KA@rift.finance',
     'K.A@rift.finance',
     'A.K@rift.finance']},
   {'name': 'Allan M. Thiga',
    'job_title': 'coo',
    'company_name': 'Rift Finance',
    'company_domain': 'rift.finance',
    'linkedin_url': 'https://ke.linkedin.com/in/allan-m-thiga-17574512',
    'linkedin_snippet': 'Finance | Operations | Entrepreneur | Advisor ... Rift Valley Apothecary specializes in the production of essential oils and tinctures.',
    'email': ['Allan@rift.finance',
     'M.@rift.finance',
     'AllanM.@rift.finance',
     'M.Allan@rift.finance',
     'Allan.M.@rift.finance',
     'AllanM@rift.finance',
     'MAllan@rift.finance',
     'AM.@rift.finance',
     'M.A@rift.finance',
     'Allan.M@rift.finance',
     'M.Allan@rift.finance',
     'A.M.@rift.finance',
     'AM@rift.finance',
     'MA@rift.finance',
     'M.A@rift.finance',
     'A.M@rift.finance']},
   {'name': 'Jesse Hunter',
    'job_title': 'recruiter',
    'company_name': 'Rift Finance',
    'company_domain': 'rift.finance',
    'linkedin_url': 'https://www.linkedin.com/in/jesse-hunter-923434129',
    'linkedin_snippet': 'Check out our open roles: League of Legends https://www.riotgames.com/en/work-with-us/jobs#product=League%20of%20Legends&office=884 Wild Rift:\xa0...',
    'email': ['Jesse@rift.finance',
     'Hunter@rift.finance',
     'JesseHunter@rift.finance',
     'HunterJesse@rift.finance',
     'Jesse.Hunter@rift.finance',
     'Hunter.Jesse@rift.finance',
     'JesseH@rift.finance',
     'HJesse@rift.finance',
     'JHunter@rift.finance',
     'HunterJ@rift.finance',
     'Jesse.H@rift.finance',
     'H.Jesse@rift.finance',
     'J.Hunter@rift.finance',
     'Hunter.J@rift.finance',
     'JH@rift.finance',
     'HJ@rift.finance',
     'H.J@rift.finance',
     'J.H@rift.finance']},
   {'name': 'Sewu-Steve T.',
    'job_title': 'partner',
    'company_name': 'Rift Finance',
    'company_domain': 'rift.finance',
    'linkedin_url': 'https://ke.linkedin.com/in/stevetawia',
    'linkedin_snippet': 'Partner@Jaza Rift Ventures | health tech, medtech, digital health | Better ... is facilitated by the Collaborative for Frontier Finance (CFF)to advance the\xa0...',
    'email': ['Sewu-Steve@rift.finance',
     'T.@rift.finance',
     'Sewu-SteveT.@rift.finance',
     'T.Sewu-Steve@rift.finance',
     'Sewu-Steve.T.@rift.finance',
     'Sewu-SteveT@rift.finance',
     'TSewu-Steve@rift.finance',
     'ST.@rift.finance',
     'T.S@rift.finance',
     'Sewu-Steve.T@rift.finance',
     'T.Sewu-Steve@rift.finance',
     'S.T.@rift.finance',
     'ST@rift.finance',
     'TS@rift.finance',
     'T.S@rift.finance',
     'S.T@rift.finance']}]}]

# %%
for people_companies in supreme_list:
    try:
        make_frontend_application(people_companies)
    except Exception as e:
        print(e)
        pass
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [34], line 16
#      11     print(person.email, "Successfully applied well done and best of luck! You are awesome!")
#      15 for people_companies in supreme_list:
# ---> 16     make_frontend_application(people_companies)
#
# Cell In [34], line 11, in make_frontend_application(person)
#       8     for i in person['email']:
#       9         send_email(i, subject, emailBody, ["/Users/tomideisawesome/Library/CloudStorage/GoogleDrive-tommideadeoye@gmail.com/My Drive/APPLICATION BOX/Tomide Adeoye CV.pdf"])
# ---> 11 print(person.email, "Successfully applied well done and best of luck! You are awesome!")
#
# AttributeError: 'dict' object has no attribute 'email'

# %%
discoverd_portfolio_companies = ["https://www.mhventures.io/portfolio", 'https://owlvc.com/portfolio.html', 'https://www.foundationventures.com/portfolio', 'https://www.adaventures.com/#portfolio', 'https://www.blockwall.capital/portfolio', 'https://www.signatureventures.com/portfolio', 'https://evolvevf.com/investments/', 'https://earlybird.com/portfolio/', 'https://outlierventures.io/portfolio/', 'https://mindset.ventures/our-companies/']
page = tomide_bs4_make_soup(discoverd_portfolio_companies[-1], 10, "incognito", False)

# %%
mh_ventures_portfolio_companies = ['https://apy.vision/',
 'https://cashmere.exchange/',
 'https://www.alloyx.xyz/',
 'https://blume.fi/',
 'https://www.panoptic.xyz/',
 'https://multievent.xyz/',
 'https://lavanet.xyz',
 'https://ethosx.xyz/',
 'https://anq.finance/',
 'https://www.lend.finance/',
 'https://www.suptho.xyz/',
 'https://onomy.io/',
 'https://www.web3port.us/',
 'https://aura.network/',
 'https://www.minima.global/',
 'https://crayondao.com/',
 'https://neptunemutual.com/',
 'https://www.rplanetnft.xyz/',
 'https://buidlerstribe.com/',
 'https://conveyorlabs.org/',
 'https://shardeum.org/',
 'https://www.mohash.co/',
 'https://www.magpiefi.xyz/',
 'https://www.seashell.com/',
 'https://smarttokenlabs.com/',
 'https://www.sonicwallet.com/',
 'https://tatsumeeko.com/',
 'https://www.wincast.io/',
 'https://www.analog.one/',
 'https://www.decaf.so/',
 'https://finblox.com/',
 'https://www.grindery.io/',
 'https://gunzillagames.com/en/',
 'https://tranching.com/',
 'https://defiyield.app/',
 'https://dexilon.io/',
 'https://www.chainport.io/']

# %% [markdown]
# ## VC ====================>

# %%
emailGenerator('Jamie', 'Burke', 'outlierventures.io')
# Out:
# Generating email list for Jamie Burke
# ['Jamie@outlierventures.io', 'JB@outlierventures.io']

# %%
targets = '''


'''
# Out:
# ['', '', 'Michael', 'Founder', 'Thomas', 'Product', 'Martin', 'FinTech', 'Benjamin', 'Architect', 'Michael', 'Business', '', '']

# %%
def make_vc_application1(person):
    subject = f"""Analyst Application | Tomide Adeoye"""
    emailBody =  vc_fund_template(person['name'][0], person['company_name']) + tomide_adeoye_contact
    if person['email'] != []:
        if len(person['email']) > 1:
            for email in person['email']:
                send_email(email, subject, emailBody, [])
        else:
            send_email(person['email'], subject, emailBody, [])
        create_csv_file('venture', [person])
        print(person['email'], "Successfully applied well done and best of luck! You are awesome!")


def target_same_company(people, company_domain):
    company = []
    try:
        for person in people:
            person = {
            'name': person.split(' '),
            'role': 'None',
            'company_name': 'Mindset Ventures',
            'company_domain': company_domain,
            "linkedin_url": None,
            "person_snippet": None,
            "company_snippet": None,
            'email': emailGenerator( person.split(' ')[0], person.split(' ')[1], company_domain)
        }
            print(person)
            company.append(person)
            # make_vc_application1(person)

    except:
        pass

    return company

target_same_company(["semanticlabs","Founder & Managing Partner","Thomas Hammerl","Product Engineer","Martin Prebio","FinTech Developer","Benjamin Ferrari","Architect & Developer","Michael Groh","Business Consultant & Architect"], "semanticlabs.at" )
# Out:
# Generating email list for Michael Jakl
# {'name': ['Michael', 'Jakl'], 'role': 'None', 'company_name': 'Mindset Ventures', 'company_domain': 'semanticlabs.at', 'linkedin_url': None, 'person_snippet': None, 'company_snippet': None, 'email': ['Michael@semanticlabs.at', 'Michael.Jakl@semanticlabs.at', 'MJ@semanticlabs.at']}
# Generating email list for Founder &
# {'name': ['Founder', '&', 'Managing', 'Partner'], 'role': 'None', 'company_name': 'Mindset Ventures', 'company_domain': 'semanticlabs.at', 'linkedin_url': None, 'person_snippet': None, 'company_snippet': None, 'email': []}
# Generating email list for Thomas Hammerl
# {'name': ['Thomas', 'Hammerl'], 'role': 'None', 'company_name': 'Mindset Ventures', 'company_domain': 'semanticlabs.at', 'linkedin_url': None, 'person_snippet': None, 'company_snippet': None, 'email': ['Thomas.Hammerl@semanticlabs.at']}
# Generating email list for Product Engineer
# ...

# %% [markdown]
# Hello Juan,
# I am happy to connect with you here. Compliments of the season!
#
# I just sent you an email mentioning my interest in working with you using my skills in
# - design, data analytics, web scraping, and automation for business intelligence,
# - research and strategy
#
# Can we discuss this more?

# %% [markdown]
# ## SOFTWARE ====================>

# %%
serenze= ['SteveLewis@honeycomb.io', 'stephanie@focuswp.co', 'housecor@gmail.com', 'christina@aranasoft.com', 'msellers@iowacomputergurus.com']

# %%
sent = [ {
   "company_name": "Thera",
   "Description": "Tackling the $1.7 trillion student loan crisis.",
   "Website": "https://getthera.com/",
   "name": "Akhil Reddy",
   "email": ["akhil@getthera.com"],
   "admiration": "all-in-one HR platform and how it addresses challenges faced by remote startups, the features for global contractor management, and your footprint in 135+ countries."
 },
  {
   "company_name": "Thera",
   "Description": "Tackling the $1.7 trillion student loan crisis.",
   "Website": "https://getthera.com/",
   "name": "Dan Burke",
   "email": ["dan@getthera.com"],
    "admiration": "all-in-one HR platform and how it addresses challenges faced by remote startups, the features for global contractor management, and your footprint in 135+ countries."
 },
 {
   "company_name": "Paigo",
   "Description": "Intelligent Billing for PaaS",
   "Website": "https://www.paigo.org/",
   "name": "Matt Sun",
   "email": ["matt.sun@paigo.tech"],
   "admiration": "cutting-edge solution for enterprise SaaS companies! The automated industry-specific pricing and service consumption measuring, combined with IaaS/PaaS billing channels, is a game-changer. The ability to start billing customers in just 5 minutes without any engineering required is truly remarkable. T"
 },
  {
   "company_name": "Paigo",
   "Description": "Intelligent Billing for PaaS",
   "Website": "https://www.paigo.org/",
   "name": "Daniel Wasserlauf",
   "email": ["daniel.wasserlauf@paigo.tech"],
   "admiration": "cutting-edge solution for enterprise SaaS companies! The automated industry-specific pricing and service consumption measuring, combined with IaaS/PaaS billing channels, is a game-changer. The ability to start billing customers in just 5 minutes without any engineering required is truly remarkable. T"
 },
 {
   "company_name": "Bluehill Payments",
   "Description": "Expanding Payment Flexibility and Lowering Rates for Merchants",
   "Website": "https://www.bluehillpayments.com/",
   "name": "Himanshu Minocha",
   "email": ["himanshu@bluehillpayments.com"],
  "admiration": "commerce and payment infrastructure coupled with your no-code automation which makes integrating multiple services seamless."
 },
  {
   "company_name": "Bluehill Payments",
   "Description": "Expanding Payment Flexibility and Lowering Rates for Merchants",
   "Website": "https://www.bluehillpayments.com/",
   "name": "Rohan Minocha",
   "email": ["rohan@bluehillpayments.com"],
   "admiration": "commerce and payment infrastructure coupled with your no-code automation which makes integrating multiple services seamless."
 },
 {
   "company_name": "Ruleset",
   "Description": "Ruleset is a no-code decision engine for consumer lending. We enable risk and legal teams to set rules for who can get a loan, without requiring engineers.",
   "Website": "https://www.ruleset.ai/",
   "name": "Logan Frederick",
   "email": ["logan@ruleset.ai",],
   "admiration": "no-code workflow automation solution for risk and legal teams - especially given the fact that I studied law for my undergraduate degree. I understand he importance of allowing professionals to save time and money with data decision making."
},
  {
   "company_name": "Ruleset",
   "Description": "Ruleset is a no-code decision engine for consumer lending. We enable risk and legal teams to set rules for who can get a loan, without requiring engineers.",
   "Website": "https://www.ruleset.ai/",
   "name": "Zheng Hao Tan",
   "email": ["zheng@ruleset.ai",],
   "admiration": "no-code workflow automation solution for risk and legal teams - especially given the fact that I studied law for my undergraduate degree. I understand he importance of allowing professionals to save time and money with data decision making."
 },{
   "company_name": "Ruleset",
   "Description": "Ruleset is a no-code decision engine for consumer lending. We enable risk and legal teams to set rules for who can get a loan, without requiring engineers.",
   "Website": "https://www.ruleset.ai/",
   "name": "Logan Frederick",
   "email": ["logan@ruleset.ai",],
   "admiration": "no-code workflow automation solution for risk and legal teams - especially given the fact that I studied law for my undergraduate degree. I understand he importance of allowing professionals to save time and money with data decision making."
},
  {
   "company_name": "Ruleset",
   "Description": "Ruleset is a no-code decision engine for consumer lending. We enable risk and legal teams to set rules for who can get a loan, without requiring engineers.",
   "Website": "https://www.ruleset.ai/",
   "name": "Zheng Hao Tan",
   "email": ["zheng@ruleset.ai",],
   "admiration": "no-code workflow automation solution for risk and legal teams - especially given the fact that I studied law for my undergraduate degree. I understand he importance of allowing professionals to save time and money with data decision making."
 },]

# %%
early_stage_startups_nigeria = [ {
   "Founders": "Ahmed Rafat",
   "Emails": "a.refaat@co-pal.com",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1JPbRS6SLQYSrMmem_wwYhKQzoiqTANfh/view?usp=share_link"
 },
 {
   "Founders": "Maame Abrema Quarm",
   "Emails": "abrema@myladder.africa",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1JtD-ffE0NuGaqPjjaKvIVDkICCaPhf0S/view"
 },
 {
   "Founders": "Adham Azzam",
   "Emails": "adham@balad.me",
   "Website": "",
   "pitchdeck": ""
 },
 {
   "Founders": "Tola Adesanmi",
   "Emails": "akintola@spleet.africa",
   "Website": "https://spleet.africa/",
   "pitchdeck": "https://docsend.com/view/jkqx6jruqvan8m49"
 },
 {
   "Founders": "Anthony Nwaizuzu",
   "Emails": "an@coincord.co",
   "Website": "Coincord.co",
   "pitchdeck": "https://docsend.com/view/hfrcm8vzxytdgvke"
 },
 {
   "Founders": "Anjolaoluwa Jegede",
   "Emails": "anjolaoluwa@logisticshubgroup.ng",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/10iRHHL8-m7y45oAnfW2oHZxfZWOaXtPQ/view?usp=sharing"
 },
 {
   "Founders": "Aramide Kasumu",
   "Emails": "aramide@bettahealthng.com",
   "Website": "",
   "pitchdeck": ""
 },
 {
   "Founders": "Olanrewaju Ogundipe",
   "Emails": "awele@pavehq.com",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1jfotyhKMvgIHBr-H_sCg-Kbkx_avdwJK/view?usp=sharing"
 },
 {
   "Founders": "Harold Jnr. Awuah-Darko",
   "Emails": "awuahdarkoharold@hotmail.com",
   "Website": "N/A",
   "pitchdeck": "https://drive.google.com/file/d/1sVZSU0uxKVsEyn_-buD-oPA2y93g6diA/view?usp=sharing"
 },
 {
   "Founders": "Mohamed Azab",
   "Emails": "azab@grinta.a",
   "Website": "WWW.GRINTA.AI",
   "pitchdeck": "https://drive.google.com/file/d/11biwm8cpAHlyAO3MlB26g5JIa6coaew-/view?usp=sharing"
 },
 {
   "Founders": "BHAVNA SURESH",
   "Emails": "bhavna@10club.team",
   "Website": "https://10club.team/",
   "pitchdeck": "https://drive.google.com/file/d/1Kms4B0YZwn1r_wVWR7byJv94aEJl85nL/view?usp=sharing"
 },
 {
   "Founders": "Boum Boum III Jr",
   "Emails": "boum@joindaba.com",
   "Website": "",
   "pitchdeck": "https://docsend.com/view/5kyse8vqxpvvrp3k"
 },
 {
   "Founders": "Cédric SOW",
   "Emails": "cedric.sow@yssah.com",
   "Website": "",
   "pitchdeck": ""
 },
 {
   "Founders": "Dante Lex",
   "Emails": "dante@onboardbase.com",
   "Website": "",
   "pitchdeck": "https://docsend.com/view/qwxd8e9j3qswi679"
 },
 {
   "Founders": "David Andefikir",
   "Emails": "davidandex01@gmail.com",
   "Website": "",
   "pitchdeck": ""
 },
 {
   "Founders": "Diego Muradas",
   "Emails": "diego@zenda.la",
   "Website": "",
   "pitchdeck": "https://docsend.com/view/d3wtrp3u9kni8tir"
 },
 {
   "Founders": "Edem Dotse",
   "Emails": "edem@swiftly.global",
   "Website": "",
   "pitchdeck": "https://docs.google.com/presentation/d/1SxIKGWfFUR_F4kHNdiJa4o-2IVhY9Az3/edit?usp=sharing&ouid=110473770630007907365&rtpof=true&sd=true"
 },
 {
   "Founders": "Emenike Olome",
   "Emails": "emenike@rabbit.africa",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1KaSGNIEQ_rAz9y_Mw8lGYVIziDvmzhHK/view"
 },
 {
   "Founders": "Francis Osifo",
   "Emails": "francis@rayda.co",
   "Website": "rayda.co",
   "pitchdeck": "https://drive.google.com/file/d/1rAXUcGhvLJLVIya6MXBqLh-mbpDk7Q-7/view"
 },
 {
   "Founders": "Garikai Govati",
   "Emails": "gazah@epionehv.com",
   "Website": "www.epionehv.com",
   "pitchdeck": "https://drive.google.com/file/d/1roGCzXrp_dYK3SU96fzRt-j-xkEYvJyH/view?usp=sharing"
 },
 {
   "Founders": "Gbenro Dara",
   "Emails": "gbenro@octamile.com",
   "Website": "https://octamile.com/",
   "pitchdeck": ""
 },
 {
   "Founders": "Gisela Van Houcke",
   "Emails": "gisela@zuriluxhair.com",
   "Website": "",
   "pitchdeck": ""
 },
 {
   "Founders": "ayo orekoya",
   "Emails": "hello@metadapp.com",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/12auRfzzXPP4c9_xGgaMYz_8QKA4X47d7/view?usp=share_link"
 },
 {
   "Founders": "obinna onyejeli",
   "Emails": "ideas@kairosangels.com",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1nVtGkib4CZ0bXpGZG9cwlLwwpYt37c2x/view?usp=sharing"
 },
 {
   "Founders": "Jeff Fashakin",
   "Emails": "jeff@payondelivery.com",
   "Website": "",
   "pitchdeck": "https://docsend.com/view/fncqsjnw36mfiq5h"
 },
 {
   "Founders": "Joel Ifenna",
   "Emails": "joel.a@uburu.ai",
   "Website": "www.uburu.ai",
   "pitchdeck": "https://drive.google.com/file/d/1XdqT0NTgdaD07ZzC0O9kHnHG-2QQTrgv/view"
 },
 {
   "Founders": "Kikelomo Fola-Ogunniya",
   "Emails": "kikelomo@jand2gidi.com.ng",
   "Website": "",
   "pitchdeck": "https://docsend.com/view/eaqrr3yfxwjpp7qz"
 },
 {
   "Founders": "Luqman",
   "Emails": "luqman@gaiholdings.com",
   "Website": "https://vampfi.com/",
   "pitchdeck": "https://drive.google.com/file/d/1pU-vw96SPquNPV36haNunyYnqCjSwKn6/view?usp=sharing"
 },
 {
   "Founders": "Marcel Okorie -",
   "Emails": "marcel@mizala.co",
   "Website": "https://mizala.co/",
   "pitchdeck": "https://drive.google.com/file/d/1DJBI_L4ouY3jVWDQFWV38tV_xOWdYAz7/view?usp=sharing"
 },
 {
   "Founders": "Michael Manirakiza\n",
   "Emails": "mike@plendify.com",
   "Website": "",
   "pitchdeck": "https://hubs.ly/Q01nKdXm0"
 },
 {
   "Founders": "Modupe O",
   "Emails": "modupe@me-cash.com",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1qpmQ4cOqIrD2f5L16-pxfv12N02mFt9K/view?usp=share_link"
 },
 {
   "Founders": "Moses Omuetha",
   "Emails": "moses@anderstek.com",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1G_dA30gETGsgNyY2yYJS-KEgrftv8FzR/view?usp=sharing"
 },
 {
   "Founders": "Kofi Genfi",
   "Emails": "mrgenfi@teamcyst.com",
   "Website": "N/A",
   "pitchdeck": "https://drive.google.com/file/d/1E41JeOD1YaSzCt6QpX5HBcreVBmAZyfd/view?usp=sharing"
 },
 {
   "Founders": "MUYIWA FAULKNER",
   "Emails": "muyiwa@blackcopper.io",
   "Website": "https://blackcopper.io/",
   "pitchdeck": "https://drive.google.com/file/d/1os8NkiKF2yIXeUmUhpsm4V75_oyy2yTQ/view?usp=sharing"
 },
 {
   "Founders": "Nebras Jemel",
   "Emails": "nebras@kaoun.com",
   "Website": "https://www.kaoun.com/",
   "pitchdeck": "https://drive.google.com/file/d/1ab2blJjtXN_KCn_FzQLz78ds7ISjlg0M/view?usp=sharing"
 },
 {
   "Founders": "Nicholas Anakwue",
   "Emails": "nicholas.anakwue@edekee.com",
   "Website": "",
   "pitchdeck": ""
 },
 {
   "Founders": "Nadeem Juma",
   "Emails": "njuma@credable.io",
   "Website": "http://www.credable.io",
   "pitchdeck": "https://drive.google.com/file/d/1yfch8Oo0gPDYOUR-6j5-qKuy1Hr6cNOz/view?usp=sharing"
 },
 {
   "Founders": "Humphrey Wrey",
   "Emails": "olumide@quickbus.com",
   "Website": "",
   "pitchdeck": "https://drive.google.com/drive/folders/1FF1DwHlJumIHVa8Hj9fIBZWU_JIRjdnc"
 },
 {
   "Founders": "Opeyemi Disu",
   "Emails": "ope@mymookie.com",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/17X-ZHdKBrOHZb_mxCr6THeSLgqxNP-rr/view?usp=sharing"
 },
 {
   "Founders": "Pierre Nwoke",
   "Emails": "pierre@sproutlyhq.com",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1WjnMlVy6V3O58URSTJlDXjAvz7aFXJex/view?usp=sharing"
 },
 {
   "Founders": "PRINCE OGBONNA",
   "Emails": "princeogbonna@gmail.com",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1CjY7P0xU6Nu354YoJoy-wz68iIqKd4pz/view?usp=sharing"
 },
 {
   "Founders": "Radhika Bhachu",
   "Emails": "radhika@ndovu.co",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1OMPCA-d4pCS1Z-i_auY4MzjVD4YNBze6/view?usp=share_link"
 },
 {
   "Founders": "Mayowa Oladipo",
   "Emails": "Samuel@foodreats.com",
   "Website": "http://onelink.to/foodreatsapp",
   "pitchdeck": "https://drive.google.com/file/d/1PrWr2bLlkDl_KWzZ4X1puEYLITzEoL5r/view"
 },
 {
   "Founders": "Seun Ayegbusi",
   "Emails": "seun.ayegbusi@insurpass.com",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1mxO37EEdJy3dMJ5i97YXdz2vSkvQPxZl/view"
 },
 {
   "Founders": "Simon Ellis",
   "Emails": "simon@smartwage.co.za",
   "Website": "https://www.smartwage.co.za/",
   "pitchdeck": "https://docsend.com/view/js4gttacm6w6nbhs"
 },
 {
   "Founders": "Sonia Kabra",
   "Emails": "sonia@buupass.com",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1aFLZXGhjIwwa1HeHgSX6d8WB_4K4JjWk/view?usp=sharing"
 },
 {
   "Founders": "Diana Owusu-Kyereko",
   "Emails": "team@makalive.com",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1xXGjyIK2-bWNtEB5eio2urhnwwpC_ngj/view?usp=sharing"
 },
 {
   "Founders": "TEMITOPE ISEDOWO,",
   "Emails": "temitope@arteri.africa",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1r1Z71JtN3xNN2yVUQD_H-dL8L258DS8H/view?usp=sharing"
 },
 {
   "Founders": "Tendai Moyo",
   "Emails": "tendai@rukahair.com",
   "Website": "",
   "pitchdeck": "https://drive.google.com/file/d/1AtOFi-UylkFidi1_FIu1cd0PLcczxBEK/view?usp=sharing"
 },
 {
   "Founders": "Tunji Olalekan",
   "Emails": "tunji@lendha.com",
   "Website": "https://lendha.com/",
   "pitchdeck": "https://drive.google.com/file/d/1LLLhs_5zmcBerr8FRSXAPuJgRj05wznU/view?usp=sharing"
 },
 {
   "Founders": "Vishal",
   "Emails": "vishal.vc1987@gmail.com",
   "Website": "",
   "pitchdeck": "https://docs.google.com/presentation/d/1NwWI2zXzRntV7yeONWy1bPGKlleaW1LHlN1pN32guNE/edit#slide=id.g1437278e4b3_0_4762"
 },
 {
   "Founders": "Wale Adeniji",
   "Emails": "wale@enlumidata.com",
   "Website": "",
   "pitchdeck": "https://docsend.com/view/5ssxc9i8qiqqg7vr"
 },]

# %%
yc_2022_companies = [
 {
   "company_name": "Ping",
   "Description": "The global neo-bank for contractors",
   "Website": "https://www.letsping.com/",
   "name": "Mary Saracco",
   "email": ["mary@letsping.com",],
   "admiration": ""
 }, {
   "company_name": "Ping",
   "Description": "The global neo-bank for contractors",
   "Website": "https://www.letsping.com/",
   "name": "Nicolas Bayerque",
   "email": ["nic@letsping.com",],
   "admiration": ""
 },
 {
   "company_name": "Cone",
   "Description": "Modern finance and accounting platform for business",
   "Website": "https://www.getcone.io/",
   "name": "Jahangir Mohammed",
   "email": ["md.jahangir27@gmail.com"],
   "admiration": ""
 }, {
   "company_name": "Cone",
   "Description": "Modern finance and accounting platform for business",
   "Website": "https://www.getcone.io/",
   "name": "Bharath Kumar Reddy",
   "email": ["sunny.lbkr@gmail.com"],
   "admiration": ""
 },
 {
   "company_name": "RootFi",
   "Description": "Tools for lending businesses (treasury, underwriting etc)",
   "Website": "https://rootfi.in/",
   "name": "Ishwar Gogineni",
   "email": ["ishwar.gogineni@rootfi.in"],
   "admiration": ""
 },
  {
   "company_name": "RootFi",
   "Description": "Tools for lending businesses (treasury, underwriting etc)",
   "Website": "https://rootfi.in/",
   "name": "Parth Shah",
   "email": ["parth.shah@rootfi.in",],
   "admiration": ""
 },
 {
   "company_name": "Tranch",
   "Description": "buy now pay later solution for SaaS sellers and professional services",
   "Website": "https://tranch.com/",
   "name": "Philip Kelvin",
   "email": ["philip.kelvin@tranch.com"],
   "admiration": ""
 },
  {
   "company_name": "Tranch",
   "Description": "buy now pay later solution for SaaS sellers and professional services",
   "Website": "https://tranch.com/",
   "name": "Beau Allison",
   "email": ["beau.allison@tranch.com",],
   "admiration": ""
 },
 {
   "company_name": "Blitz",
   "Description": "Blitz is a no-code platform for operations teams. We make it easy to structure and automate very manual processes - such as onboarding a new partner or resolving customer tickets. \nNon-technical users don't have to use spreadsheets anymore or depend on developers for internal tools. With Blitz, they can create interfaces and workflows on top of a flexible database, and easily scale their operations. ",
   "Website": "https://www.blitznocode.com/",
   "name": "Clement Bruneau",
   "email": ["clement@blitznocode.com"],
   "admiration": ""
 },
  {
   "company_name": "Blitz",
   "Description": "Blitz is a no-code platform for operations teams. We make it easy to structure and automate very manual processes - such as onboarding a new partner or resolving customer tickets. \nNon-technical users don't have to use spreadsheets anymore or depend on developers for internal tools. With Blitz, they can create interfaces and workflows on top of a flexible database, and easily scale their operations. ",
   "Website": "https://www.blitznocode.com/",
   "name": "Loic Veillard",
   "email": ["loic@blitznocode.com"],
   "admiration": ""
 },
 {
   "company_name": "Excheqr",
   "Description": "Institutional-grade digital asset infrastructure",
   "Website": "https://www.excheqr.xyz/",
   "name": "Tanmay Chaudhari",
   "email": ["tanmay@excheqr.xyz"],
   "admiration": ""
 }, {
   "company_name": "Excheqr",
   "Description": "Institutional-grade digital asset infrastructure",
   "Website": "https://www.excheqr.xyz/",
   "name": "Vivek Kumar",
   "email": ["kmr.vivek15@gmail.com"],
   "admiration": ""
 },
 {
   "company_name": "Banabo",
   "Description": "Cookieless Marketing Attribution: Built on top of anonymous identification. No need to collect, process, or store a visitor’s personal data",
   "Website": "https://www.banabo.io/",
   "name": "Colin Snyder",
   "email": ["colin@banabo.io"],
   "admiration": ""
 },
  {
   "company_name": "Banabo",
   "Description": "Cookieless Marketing Attribution: Built on top of anonymous identification. No need to collect, process, or store a visitor’s personal data",
   "Website": "https://www.banabo.io/",
   "name": "Ben Reilly",
   "email": ["ben@banabo.io"],
   "admiration": ""
 },
 {
   "company_name": "Uplink",
   "Description": "web application associates workflow (open, in review, rejected, complete) with each document req so you can track status of individ. document requests across projects.",
   "Website": "https://www.uplinkapp.io/",
   "name": "Alex Maher",
   "email": ["alex@uplinkapp.io"],
   "admiration": ""
 }, {
   "company_name": "Uplink",
   "Description": "web application associates workflow (open, in review, rejected, complete) with each document req so you can track status of individ. document requests across projects.",
   "Website": "https://www.uplinkapp.io/",
   "name": "Brady Ochse",
   "email": ["brady@uplinkapp.io"],
   "admiration": ""
 },
 {
   "company_name": "Monterey",
   "Description": "Monterey is building the co-pilot for product development. Monterey achieves this by replacing documents with smart, use-case-centric workflows that help product leads strategize, measure, and align. By helping to discover product dependency and interconnectivity, Monterey guards and boosts product velocity for hyper growing teams.",
   "Website": "https://www.monterey.ai/",
   "name": "Chun Jiang",
   "email": ["chun@monterey.ai"],
   "admiration": ""
 }, {
   "company_name": "Monterey",
   "Description": "Monterey is building the co-pilot for product development. Monterey achieves this by replacing documents with smart, use-case-centric workflows that help product leads strategize, measure, and align. By helping to discover product dependency and interconnectivity, Monterey guards and boosts product velocity for hyper growing teams.",
   "Website": "https://www.monterey.ai/",
   "name": "Ben Kramer",
   "email": ["ben@monterey.ai"],
   "admiration": ""
 },
 {
   "company_name": "NewsCatcher",
   "Description": "News search enginge for machines",
   "Website": "https://newscatcherapi.com/",
   "name": "Artem Bugara",
   "email": ["artem@newscatcherapi.com"],
   "admiration": ""
 }, {
   "company_name": "NewsCatcher",
   "Description": "News search enginge for machines",
   "Website": "https://newscatcherapi.com/",
   "name": "Maksym Sugonyaka",
   "email": ["kizy625@gmail.com"],
   "admiration": ""
 },
 {
   "company_name": "Relate",
   "Description": "Relate is a simple, collaborative sales CRM for startups and SMBs.",
   "Website": "https://www.relate.so/",
   "name": "Christopher Chae",
   "email": "",
   "admiration": ""
 },{'company_name': 'MovingLake',
  'Description': 'MovingLake makes it easy to consume APIs in realtime for event-driven architectures. We create as well as manage webooks for any API which needs it.',
  'Website': 'https://www.movinglake.com',
  'name': 'Andres Paez',
  'email': ['andres@movinglake.com'],
  'admiration': 'real-time API data connectors and the seamless integration they enable. Being a Y Combinator backed business I recognize that you are in a comfortable palce to help businesses make data-driven decisions faster. I am certain that my data analytics expereince will also prove helpful to you.'},
 {'company_name': 'MovingLake',
  'Description': 'MovingLake makes it easy to consume APIs in realtime for event-driven architectures. We create as well as manage webooks for any API which needs it.',
  'Website': 'https://www.movinglake.com',
  'name': 'Edgar Cabrera',
  'email': ['edgar@movinglake.com'],
  'admiration': 'real-time API data connectors and the seamless integration they enable. Being a Y Combinator backed business I recognize that you are in a comfortable palce to help businesses make data-driven decisions faster. I am certain that my data analytics expereince will also prove helpful to you.'},

]

# %%
unseen = [ {
   "company_name": "Garage",
   "Description": "Auto parts marketplace for Africa",
   "Website": "https://www.garagemobility.com/",
   "name": "",
   "email": "",
   "admiration": ""
 },
 {
   "company_name": "Levers",
   "Description": "",
   "Website": "",
   "name": "",
   "email": "",
   "admiration": ""
 },
 {
   "company_name": "Homli",
   "Description": "",
   "Website": "",
   "name": "",
   "email": "",
   "admiration": ""
 },
 {
   "company_name": "Gullak",
   "Description": "",
   "Website": "",
   "name": "",
   "email": "",
   "admiration": ""
 },
 {
   "company_name": "Boostly",
   "Description": "",
   "Website": "",
   "name": "",
   "email": ""
 },  {
   "company_name": "Polymer",
   "Description": "Optimal prices, revealed by real customers.",
   "Website": "https://trypolymer.com",
   "name": "",
   "email": "",
   "admiration": ""
 },{
   "company_name": "Relate",
   "Description": "Relate is a simple, collaborative sales CRM for startups and SMBs.",
   "Website": "https://www.relate.so/",
   "name": "Sangyong Jung",
   "email": "",
   "admiration": ""
 },]

# %%
send_to = [ {'company_name': 'Activepieces',
  'Description': 'Data integration tools for developers',
  'Website': 'https://www.activepieces.com/',
  'name': 'Ashraf Samhouri',
  'email': 'ash@activepieces.com',
  'admiration': ''},
 {'company_name': 'Activepieces',
  'Description': 'Data integration tools for developers',
  'Website': 'https://www.activepieces.com/',
  'name': 'Mohammad AbuAboud',
  'email': 'mo@activepieces.com',
  'admiration': ''},
 {'company_name': 'Maya Labs',
  'Description': 'Building programs that build other programs',
  'Website': 'https://www.mayalabs.io/',
  'name': 'Sibesh Kar',
  'email': 'sibesh@mayalabs.io',
  'admiration': ''},
 {'company_name': 'Maya Labs',
  'Description': 'Building programs that build other programs',
  'Website': 'https://www.mayalabs.io/',
  'name': 'Shubham Mishra',
  'email': 'shubham@mayalabs.io',
  'admiration': ''},
 {'company_name': 'Iollo',
  'Description': 'iollo is a subscription service that helps you live healthier and much longer. We measure 500+ health-related molecules in your blood to match you with action plans such as dietary, behavioral, and therapeutic interventions that let you extend your healthy lifespan and slow down how fast you age.',
  'Website': 'https://www.iollo.com/',
  'name': 'Brent LaRue',
  'email': 'brent@iollo.com',
  'admiration': ''},
 {'company_name': 'Iollo',
  'Description': 'iollo is a subscription service that helps you live healthier and much longer. We measure 500+ health-related molecules in your blood to match you with action plans such as dietary, behavioral, and therapeutic interventions that let you extend your healthy lifespan and slow down how fast you age.',
  'Website': 'https://www.iollo.com/',
  'name': 'Daniel Gomari',
  'email': 'dan@iollo.com',
  'admiration': ''},
 {'company_name': 'Dr. Treat',
  'Description': 'Dr. Treat is a tech enabled modern veterinary care company offering virtual and in-clinic services to pet parents. We are building the largest pet health company powered by technology and driven by data to offer highly personalized & preventative care for every pet.',
  'Website': 'https://www.drtreat.com/',
  'name': 'Rakesh Tondon',
  'email': 'rakesh@drtreat.com',
  'admiration': ''},
 {'company_name': 'Dr. Treat',
  'Description': 'Dr. Treat is a tech enabled modern veterinary care company offering virtual and in-clinic services to pet parents. We are building the largest pet health company powered by technology and driven by data to offer highly personalized & preventative care for every pet.',
  'Website': 'https://www.drtreat.com/',
  'name': 'charlie bowman',
  'email': 'charlie@drtreat.com',
  'admiration': ''},
 {'company_name': 'Numi Foods',
  'Description': 'We create next generation seafood products in symbiosis with our oceans',
  'Website': 'http://www.numifoods.co',
  'name': 'Marilena Schmich',
  'email': 'marilena@numifoods.co',
  'admiration': ''},
 {'company_name': 'Numi Foods',
  'Description': 'We create next generation seafood products in symbiosis with our oceans',
  'Website': 'http://www.numifoods.co',
  'name': 'Anton Pluschke',
  'email': 'anton@numifoods.co',
  'admiration': ''},
 {'company_name': 'Roforco',
  'Description': 'Metaverse gaming studio for Roblox',
  'Website': 'https://roforco.com/',
  'name': 'Tom Middleton',
  'email': 'tom@roforco.com',
  'admiration': ''},
 {'company_name': 'Roforco',
  'Description': 'Metaverse gaming studio for Roblox',
  'Website': 'https://roforco.com/',
  'name': 'Brain Xiang',
  'email': 'brain@roforco.com',
  'admiration': ''},
 {'company_name': 'ULT',
  'Description': 'Uber for Gamers',
  'Website': 'http://www.ult.com/',
  'name': 'Sam Wang',
  'email': 'sam@ult.com',
  'admiration': ''},
 {'company_name': 'ULT',
  'Description': 'Uber for Gamers',
  'Website': 'http://www.ult.com/',
  'name': 'Jason Zhang',
  'email': 'jason@ult.com',
  'admiration': ''},
 {'company_name': 'Zoltar Labs',
  'Description': 'Zoltar is a developer tool for Web3 companies to 10x the velocity of smart contract testing and deployment. Most existing Web3 developer tools were built for single developer utility, and collaborative workflows such as testing amongst teammates often slows down the overall developer velocity.',
  'Website': 'https://www.zoltarlabs.com/',
  'name': 'Jensen Kuo',
  'email': 'jensen@zoltarlabs.com',
  'admiration': ''},
 {'company_name': 'Zoltar Labs',
  'Description': 'Zoltar is a developer tool for Web3 companies to 10x the velocity of smart contract testing and deployment. Most existing Web3 developer tools were built for single developer utility, and collaborative workflows such as testing amongst teammates often slows down the overall developer velocity.',
  'Website': 'https://www.zoltarlabs.com/',
  'name': 'James Chen',
  'email': 'james@zoltarlabs.com',
  'admiration': ''},
 {'company_name': 'Immuna',
  'Description': 'Trust and safety infra for Web3',
  'Website': 'https://www.immuna.xyz',
  'name': 'Gaurav Aggarwal',
  'email': 'gaurav@immuna.xyz',
  'admiration': ''},
 {'company_name': 'Immuna',
  'Description': 'Trust and safety infra for Web3',
  'Website': 'https://www.immuna.xyz',
  'name': 'Anuja Verma',
  'email': 'anuja@immuna.xyz',
  'admiration': ''},
 {'company_name': 'Blockscope',
  'Description': 'Cloud tools & backend services for Web3 developers',
  'Website': 'http://www.blockscope.tech/',
  'name': 'Adit Patel',
  'email': 'adit@blockscope.tech',
  'admiration': ''},
 {'company_name': 'Blockscope',
  'Description': 'Cloud tools & backend services for Web3 developers',
  'Website': 'http://www.blockscope.tech/',
  'name': 'Maharshi Patel',
  'email': 'maharshi@blockscope.tech',
  'admiration': ''},
 {'company_name': 'Lion Pose',
  'Description': 'Clinical skin care for people of color (launching in Sephora)',
  'Website': 'lionpose.com',
  'name': 'Madhu Punjabi',
  'email': 'madhu@lionpose.com',
  'admiration': ''},
 {'company_name': 'Lion Pose',
  'Description': 'Clinical skin care for people of color (launching in Sephora)',
  'Website': 'lionpose.com',
  'name': 'Nisha Phatak',
  'email': 'nisha@lionpose.com',
  'admiration': ''},
 {'company_name': 'Be Golden',
  'Description': 'Monitor inflammation at home',
  'Website': 'begolden.io',
  'name': 'Sneh Patel',
  'email': 'sneh@begolden.io',
  'admiration': ''},
 {'company_name': 'Be Golden',
  'Description': 'Monitor inflammation at home',
  'Website': 'begolden.io',
  'name': 'Kimberly McManus',
  'email': 'kimberly@begolden.io',
  'admiration': ''},
 {'company_name': 'Momentu',
  'Description': 'Corporate mental health for LATAM',
  'Website': 'momentu.co',
  'name': 'Noam Grebler Farras',
  'email': 'noam@momentu.co',
  'admiration': ''},
 {'company_name': 'Momentu',
  'Description': 'Corporate mental health for LATAM',
  'Website': 'momentu.co',
  'name': 'JP Montoya',
  'email': 'jpmontoya@momentu.co',
  'admiration': ''},
 {'company_name': 'InVision Medical Technologies',
  'Description': 'AI Heart Disease Dx',
  'Website': 'invisionmedtech.com',
  'name': 'David Ouyang',
  'email': 'david@invisionmedtech.com',
  'admiration': ''},
 {'company_name': 'InVision Medical Technologies',
  'Description': 'AI Heart Disease Dx',
  'Website': 'invisionmedtech.com',
  'name': 'Bryan He',
  'email': 'bryanhe@invisionmedtech.com',
  'admiration': ''},
 {'company_name': 'Morf health',
  'Description': 'Data integration for health care',
  'Website': 'https://morf.health',
  'name': 'Montana Scher',
  'email': 'montana@morf.health',
  'admiration': ''},
 {'company_name': 'Morf health',
  'Description': 'Data integration for health care',
  'Website': 'https://morf.health',
  'name': 'James Thompson',
  'email': 'jamesthompsonoxford@gmail.com',
  'admiration': ''},
 {'company_name': 'Almond',
  'Description': 'OneMedical for OBGYN',
  'Website': 'almondobgyn.com',
  'name': 'Tara Raffi',
  'email': 'tara@almondobgyn.com',
  'admiration': ''},
 {'company_name': 'Almond',
  'Description': 'OneMedical for OBGYN',
  'Website': 'almondobgyn.com',
  'name': 'Carly Allen',
  'email': 'carly@almondobgyn.com',
  'admiration': ''},
 {'company_name': 'Delegasi',
  'Description': 'Automated accounting service for small businesses in Indonesia',
  'Website': 'https://delegasi.co/',
  'name': 'Okky Pratama',
  'email': 'okky@delegasi.co',
  'admiration': ''},
 {'company_name': 'Delegasi',
  'Description': 'Automated accounting service for small businesses in Indonesia',
  'Website': 'https://delegasi.co/',
  'name': 'Ans Syuhada',
  'email': 'ans@delegasi.co',
  'admiration': ''},
 {'company_name': 'Payable',
  'Description': 'No-code online payment collection for Indonesian businesses.',
  'Website': 'https://www.payable.id/',
  'name': 'Faza Fahleraz',
  'email': 'faza@payable.id',
  'admiration': ''},
 {'company_name': 'Payable',
  'Description': 'No-code online payment collection for Indonesian businesses.',
  'Website': 'https://www.payable.id/',
  'name': 'Gery Nugraha',
  'email': 'gery@payable.id',
  'admiration': ''},
 {'company_name': 'Pasito',
  'Description': 'Saving companies money on healthcare and payroll',
  'Website': 'https://joinpasito.com/',
  'name': 'Pauline Roteta',
  'email': 'pauline@joinpasito.com',
  'admiration': ''},
 {'company_name': 'Pasito',
  'Description': 'Saving companies money on healthcare and payroll',
  'Website': 'https://joinpasito.com/',
  'name': 'Ignacio Ampuero',
  'email': 'ignacio@joinpasito.com',
  'admiration': ''},
 {'company_name': 'Ruffo',
  'Description': 'Cross-border real estate transactions made easy',
  'Website': 'https://www.ruffo.com/',
  'name': 'Noe Branagan',
  'email': 'noe@ruffo.com',
  'admiration': ''},
 {'company_name': 'Ruffo',
  'Description': 'Cross-border real estate transactions made easy',
  'Website': 'https://www.ruffo.com/',
  'name': 'Luis Pellerano',
  'email': 'luis@ruffo.com',
  'admiration': ''},
 {'company_name': 'Sunlight',
  'Description': 'The Universal Card-On-File API',
  'Website': 'https://www.sunlightapi.com/',
  'name': 'Guy Ziv',
  'email': 'guy@sunlightapi.com',
  'admiration': ''},
 {'company_name': 'Sunlight',
  'Description': 'The Universal Card-On-File API',
  'Website': 'https://www.sunlightapi.com/',
  'name': 'Leo Chanea',
  'email': 'leo@sunlightapi.com',
  'admiration': ''},
 {'company_name': 'Disclo',
  'Description': 'Health disclosure and accommodation management platform',
  'Website': 'http://www.disclo.com/',
  'name': 'Hannah Olson',
  'email': 'hannah@disclo.com',
  'admiration': ''},
 {'company_name': 'Disclo',
  'Description': 'Health disclosure and accommodation management platform',
  'Website': 'http://www.disclo.com/',
  'name': 'Kai Keane',
  'email': 'kai@disclo.com',
  'admiration': ''},
 {'company_name': 'Drip',
  'Description': 'BNPL for Brazil',
  'Website': 'https://dripapp.com.br/',
  'name': 'Patrick Sterea',
  'email': 'patrick@dripapp.com.br',
  'admiration': ''},
 {'company_name': 'Drip',
  'Description': 'BNPL for Brazil',
  'Website': 'https://dripapp.com.br/',
  'name': 'Bianca Orsini',
  'email': 'bianca@usedrip.com.br',
  'admiration': ''}]

# %% [markdown]
# ### PYTHON =========>

# %%
def make_python_application(person):
    subject = f"""Python Engineer Application | Tomide Adeoye"""
    emailBody =  person_python_engineer_application("hire|py") + tomide_adeoye_contact
    send_email(person, subject, emailBody, ["/Users/tomideisawesome/Library/CloudStorage/GoogleDrive-tommideadeoye@gmail.com/My Drive/APPLICATION BOX/Tomide Adeoye CV.pdf"])
    print(person, "Successfully applied well done and best of luck! You are awesome!")

make_python_application("info@hire-py.tech")
# Out:
# info@hire-py.tech Successfully applied well done and best of luck! You are awesome!

# %% [markdown]
# #### FRONTEND =========>

# %%
def make_frontend_application(person):
    subject = f"""Building {person['company_name']} | Fullstack Engineer Application | Tomide Adeoye"""
    emailBody = person_frontend_engineer_application(person['name'][0], person['company_name'], person['admiration']) + verbose_tomide_adeoye_contact
    
    if len(person['email']) == 1:
        send_email(person['email'], subject, emailBody, ["/Users/tomideisawesome/Library/CloudStorage/GoogleDrive-tommideadeoye@gmail.com/My Drive/APPLICATION BOX/Tomide Adeoye CV.pdf"])
    else:
        for i in person['email']:
            send_email(i, subject, emailBody, ["/Users/tomideisawesome/Library/CloudStorage/GoogleDrive-tommideadeoye@gmail.com/My Drive/APPLICATION BOX/Tomide Adeoye CV.pdf"])

    print(person['email'], "Successfully applied well done and best of luck! You are awesome!")

# %%
for i in[ ]:
    make_frontend_application(i)
# Out:
# ['andres@movinglake.com'] Successfully applied well done and best of luck! You are awesome!
# ['edgar@movinglake.com'] Successfully applied well done and best of luck! You are awesome!

# %% [markdown]
# ## PRODUCT ====================>
