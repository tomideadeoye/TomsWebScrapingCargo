# %%
import extract_msg
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen.canvas import Canvas
import docx
import os

# %%
directory = '/Users/tomideisawesome/Documents/GitHub/TomsWebScrapingCargo/pluralsight_files/msg'
# get all the files in the directory

files = os.listdir(directory)

for file in files:
    try:
        print(f"========================================================={file}==================================")
        # print new line
    

        msg = extract_msg.openMsg( directory + "/" + file)
        print(msg.recipients)
        print(msg.date)
        print(msg.sender)
        print(msg.subject)
        print(msg.body)
        print(msg.attachments)
    except:
        pass
# Out:
# ['Future Africa __ TLG Potential Pipeline(1).msg',
#  'Boost Notes.msg',
#  'Capsa Call (Future Africa)(1).msg',
#  'MarketForce __ TLG Intro Call .msg',
#  'Capsa Call (Future Africa).msg',
#  'Boost Notes(1).msg',
#  'Liveable (Future Africa) __ Notes.msg',
#  'Future Africa __ TLG Potential Pipeline.msg',
#  'FW_ Octo __ TLG Capital _ Venture Debt Opportunity(1).msg',
#  'Send __ TLG Capital _ Screening + Notes .msg',
#  'Fw_ Edves __TLG Call Notes .msg',
#  'Fw_ Edves __TLG Call Notes (1).msg',
#  'Liveable (Future Africa) __ Notes(1).msg',
#  'FW_ Octo __ TLG Capital _ Venture Debt Opportunity.msg',
#  'Send __ TLG Capital _ Screening + Notes (1).msg',
#  'MarketForce __ TLG Intro Call (1).msg']

# %%
for file in files:
    try:
        print(f"========================================================={file}==================================")
        # print new line
    

        msg = extract_msg.openMsg( directory + "/" + file)
        print(msg.recipients)
        print(msg.date)
        print(msg.sender)
        print(msg.subject)
        print(msg.body)
        print(msg.attachments)
    except:
        pass
# Out:
# =========================================================Future Africa __ TLG Potential Pipeline(1).msg==================================
# ...
# Thu, 25 Aug 2022 10:21:25 +0100
# Amartya Maheshwari <amartya.maheshwari@tlgcapital.com>
# Future Africa <> TLG Potential Pipeline
# Hi Team,
#
#
#
#
# Attached below table that summarises potential venture debt candidates from Future Africa's portfolio. Unfortunately, I won't be here to interact with some of these companies, but they sound like exciting projects and will be helpful in diversifying our venture debt pipeline. This table with the screening/decks should be sufficient going into intro calls.
#
#
#
#
# *** I'll be working on a primer we can send to these companies (similar to the VC primer but slide 2 different). Pls let me know if you have any suggestions on key ideas/points we should include!
#
#
#
#
#
#
#
# Future Africa Venture-Debt Candidates:
#
#
#
#
#
# Calls already taken/set-up: Green shaded
#
#
# ...

# %%
def convert_to_docx(direct, string, filename):

    

    # create a new Word document
    doc = docx.Document()

    # add the string to the document as a paragraph
    doc.add_paragraph(string)

    # save the Word document
    doc.save(filename)

# %%
for file in files:

    # get the full path to the file
    full_path = os.path.join(directory, file)

    # check if the file is a file and not a directory
    if os.path.isfile(full_path ):

        # open the file
        with open(full_path 
    
                # read the contents of the file
                contents = f.read()
    
                # print the contents of the file
                print(contents)
    
                # convert the file to a docx file
                convert_to_docx(full_path, contents, file + '.docx')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 1.3 MB/s eta 0:00:0000:0100:010m
# ...
