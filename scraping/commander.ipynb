# %%
commands = '''
yarn start
yarn start:dev
git pull development
git pull origin development
git pull origin master
pub get
flutter pub get
ls
cd Development
ls
mkdir tryDjango
cd tryDjango
virtualenv
ls
virtualenv -p python3 .
source bin/activate
pip install django===2.0.7
pip install django===2.0.7
deactivate
pip freeze
source bin/activate
pip freeze
which python
ls
mkdir src
ls
cd src
django-admin startproject tyrDjango
ls
cd ..
ls
cd src
ls
rm -rf tyrDjango
ls
django-admin startproject trydjango .
ls
python manage.py runserver
ls
cd ..
ls
cd ..
l
code .
yran start
yarn start
python manage.py createsuperuser
ls
yarn star:dev
yarn start:dev
git pull origin development
yarn start
yarn start
source /Users/tomideisawesome/Development/tryDjango/bin/activate
ls
cd src
ls
python manage.py startapp products
source /Users/tomideisawesome/Development/tryDjango/bin/activate
python manage.py migrate
ls
source bin/activate
python manage.py migrate
cd src
python manage.py migrate
python manage.py runserver
python manage.py migrate
python manage.py createsuperuser
python manage.py runserver
source /Users/tomideisawesome/Development/tryDjango/bin/activate
yarn start:dev
yarn add @mui/lab @mui/material
git show REVISION:pages/Presentation/Footer
git show HEAD~2:pages/Presentation/Footer
git show HEAD~2:src/pages/Presentation/Footer
git show HEAD~2:/Users/tomideisawesome/Documents/GitHub/Tomide-Adeoye-Portfolio/src/pages/Presentation/Footer
git show HEAD~2:/Users/tomideisawesome/Documents/GitHub/Tomide-Adeoye-Portfolio/src/pages/Presentation/Footer.jsx
git show HEAD~2:/Users/tomideisawesome/Documents/GitHub/Tomide-Adeoye-Portfolio/src/pages/Presentation/Footer.js
git show HEAD~2:src/pages/Presentation/index.js
git show HEAD~2:src/pages/Presentation/Footer.jsx
git show HEAD~2:src/pages/Presentation/Footer.jsx
yarn add material-ui-search-bar
yarn start
yarn start
yarn start
npx kill-port 3000
sudo kill -9 `sudo lsof -t -i:3000`
yarn add material-ui-search-bar
yarn start
yarn remove material-ui-search-bar
yarn start
yarn start
yarn remove @mui/lab
yarn start
yarn add @mui/material 
yarn start
yarn remove 
yarn remove "@mui/material
yarn remove @mui/material
yarn add "@mui/material
yarn add @mui/material
yarn start
yarn remove node_modules
yarn && yarn start
yarn
yarn add react-syntax-highlighter
yarn add material-ui-search-bar
sudo kill -9 `sudo lsof -t -i:3000`
yarn add @material-ui/core
yarn add @material-ui/icons 
git pull origin Test
git pull origin Test
yarn start:dev
scrapy shell
scrapy
yarn start: testing
yarn start:testing
yarn start:dev
yarn start:testing
yarn start:dev
yarn start:testing
source /Users/tomideisawesome/Documents/GitHub/TomsWebScrapingCargo/env/bin/activate
pip3 install dryscrape
git show HEAD~1:src/pages/analyst-dashboard/components/visualisations/chart-box.js
git show HEAD~2:src/pages/analyst-dashboard/components/visualisations/chart-box.js
git show HEAD~3:src/pages/analyst-dashboard/components/visualisations/chart-box.js
git show HEAD~4:src/pages/analyst-dashboard/components/visualisations/chart-box.js   
git pull origin Test
yarn start:testing
yarn start:dev
git pull origin Test
git pull origin Test
yarn start:dev
git pull origin Test
yarn start:dev
git pull origin Test
git pull origin Test
yarn start:dev
git pull origin Test
git pull origin Test
git pull origin Test
yarn start:dev
yarn start:testing
yarn start:test
yarn start:dev
arn start:test
yarn start:test
yarn start:dev
yarn start:dev
git pull origin Test
yarn start:dev
yarn start:dev
yarn start:dev
yarn start:dev
yarn start:dev
yarn start:dev
git pull origin Test 
git pull origin Test
git pull origin Test
yarn start:dev
git pull origin development 
yarn start:dev
git pull origin Test
yarn start:dev
yarn start:dev
git pull origin development
git pull origin Test
git pull origin Test
git pull origin Test
yarn start:dev
git pull origin Test
yarn start:dev
git pull origin Test
yarn start
yarn start:dev
git pull origin Test
yarn start:dev
yarn start:dev
git pull origin Test
yarn start:dev
git pull origin Test
yarn start:dev
git pull origin Test
yarn start:dev
git pull origin Test
yarn start:dev
git pull origin Test
git pull origin Test
yarn start:dev
yarn start:dev
yarn start:dev
git pull origin Test
yarn start:dev
yarn start:dev
git pull origin Test
git pull origin Test
yarn start:dev
git pull origin Test
yarn start:dev
git pull origin Test
git pull origin Test
yarn start:dev
yarn start:dev
git checkout Test
yarn star:prod
git pull origin Test
git pull origin Test
yarn start:dev
ls
cd ..
open Desktop
yarn start:dev
git pull orgin Test
git pull origin Test
yarn start:dev
git pull origin Test
yarn start:dev
yarn start:dev
git pull origin master
git pull origin Test
git pull origin master
git pull master
git pull origin master
yarn start:dev
flutter upgrade
yarn start:dev
cd ~
ls
cd Development
ls
cd flutter
pwd
flutter doctor
flutter doctor --android-licenses
flutter doctor
flutter doctor
/Users/tomideisawesome/Development/flutter --install "cmdline-tools;latest"
sudo  /Users/tomideisawesome/Development/flutter --install "cmdline-tools;latest" 
flutter  --install "cmdline-tools;latest"
flutter -h
flutter doctor --android-licenses
git pull orgin master
git pull origin master
git pull origin master
yarn start:dev
git pull origin Test
yarn start: prod
yarn start:pord
git pull origin Test
git pull origin Test
yarn start:dev
git pull origin Test
git pull origin Test
git pull origin Test
LS
ls
cd ..
ls
open Desktop
yarn start:dev
yarn start:dev
yarn start:dev
pwd
source  ../venv/bin/activate
pip list
code .
yarn start:dev
git pull origin Test
yarn 
yarn start:dev
yarn start:dev
git pull origin Test
yarn start:dev
ls
pwd
yarn start:prod
open ios/Runner.xcworkspace
flutter pub add animated_splash_screen
package:page_transition/page_transition.dart
flutter pub add package:page_transition/page_transition.dart
flutter pub add page_transition
flutter pub add cached_network_image
sudo gem uninstall ffi && sudo gem install ffi
sudo gem uninstall ffi && sudo gem install ffi -- --enable-libffi-alloc
brew install libffi
brew install cocoapods
yarn start:dev
git status
git pull origin Test
git dd .
git add .
git commit -m'Tomide update'
git push
git pull origin Test
git pull origin main
yarn add @mui/styles
yarn start
yarn add react-router && react-router-dom --save && yarn start
yarn add @mui/material @emotion/react @emotion/styled
yarn add @mui/icons-material
yarn add @mui/styles
yarn && yarn start
yarn
yarn add react-router-dom --save
yarn add @mui/material @emotion/react @emotion/styled
yarn add @mui/icons-material
yarn start:dev
git pull origin Test && yarn && yarn start:dev
yarn start
git pull origin main
git pull origin main
yarn start
yarn && yarn start:dev
git checkout navigation
yarn start
yarn add react-color --save
git checkout main
git pull origin main
git chackout navigation
git checkout navigation
git pull origin navigation
yarn start
yarn && yarn start
yarn start
yarn && yarn start
yarn add file-saver
yarn start 
ls
open desktop
open .
clear
yarn && yarn start
yarn start
yarn start
ls 
cd application_maker  
Code .
yarn add eslint-config-react-app -D
yarn start
yarn remove  eslint-config-react-app -D
yarn install:clean
yarn 
yarn start
code .
cd /Users/tomideisawesome/Development/flutter_delete1/hive_minds/hive_minds 
code .
flutter run
flutter pub add ar_flutter_plugin
flutter run -v
flutter run
flutter fix
flutter flutter -h
flutter -h
flutter run
flutter run -v
flutter run
flutter run -v
yanr start:prod
git pull origin Test
flutter run -v
flutter run 
flutter devices
flutter run --scan
fluter scan
flutter scan
flutter pub get color_extensions
git show HEAD~2:src/pages/analyst-dashboard/components/sortable-box.js
yarn start origin test
yarn start:dev
yarn add --save react-copy-to-clipboard
yarn add react-copy-to-clipboard
ls	
open .
yarn start
yarn add react-animated-text-content
yarn start
yarn start
yarn start
flutter clean
flutter doctor
npm init
npm init --d
node index.js
node index
npm i express
node index
npm i cors express nodemon
nodemon index
npm install -g nodemon
sudo npm install -g nodemon
nodemon index
npm install graphql -save
nodemon index
npm install --save seerbit-nodejs
npm install @types/node ts-node 
npm i -D typescript
tsc --init 
npm install typescript -g
sudo npm install typescript -g
tsc --init 
npm remove express
npm install -D @types/express
npm install -D ts-node-dev
npm i express
npm install axios\
npm run dev
sudo nano /etc/paths
echo $path
open /Users/tomideisawesome/Library/Application Support/Google/Chrome/
open /Users/tomideisawesome/Library/Application Support/Google/Chrome/Profile 1
open "/Users/tomideisawesome/Library/Application Support/Google/Chrome/Profile 1"
sudo vi /etc/paths
cd /usr/local/bin/ 
xattr -d com.apple.quarantine chromedriver 
open /Users/tomideisawesome/Library/Application Support/Google/Chrome/Profile 1
open /Users/tomideisawesome/Library/Application Support/Google/Chrome/Profile 1
open "/Users/tomideisawesome/Library/Application Support/Google/Chrome/Profile 1"
yarn start
yarn add --save typescript @types/node @types/react @types/react-dom @types/jest
yarn remove prop-types
yarn start
yarn add prop-types
yarn start
chromedriver
yarn start
yarn start
yarn && yarn start
yarn start
yarn add 16.8.6
yarn remove @types/react
yarn add @types/react@16.8.6
yarn start
yarn add @types/react@17.0.0
yarn start
yarn start dev
git pull origin Test
yarn start:dev
git checkout Test
yarn start dev
yarn && yarn start:dev
yarn start
github .
github .
yarn start:dev
yarn start
yarn remove axios
yarn remove file-saver
yarn run deploy
github .
yarn add gh-pages --save-dev
yarn start
git checkout gh-pages
git checkout main
yarn add gh-pages
cd build
code .
yarn run predeploy
yarn start
yarn add gh-pages --save-dev
yarn add --dev gh-pages
yarn remove gh-pages
yarn add --dev gh-pages
yarn start
yarn start:dev
git pull origin dev
dart pub cache clean
open -a Simulator
cd /Users/tomideisawesome/Desktop/Flutter\ kits/argon-flutter-master 
code .
flutter test
flutter run lib/main.dart
git checkout dev
open .zprofile        
npm start
yarn remove typescript
npm remove typescript
npm remove ts-node
npm remove ts-node
npm remove @types/node
yarn reomve @types/express
npm remove @types/express
open -a simulator 
open ~/.zprofile
git pull origin
git pull origin
yarn && yarn start:dev
open /Users/tomideisawesome/Library/CloudStorage/GoogleDrive-tommideadeoye@gmail.com/My Drive/APPLICATION BOX/Tomide Adeoye CV.docx
/Users/tomideisawesome/Library/CloudStorage/GoogleDrive-tommideadeoye@gmail.com/My\ Drive/APPLICATION\ BOX/Tomide\ Adeoye\ CV.pdf; 
yarn start
/Applications/Google\ Chrome.app/Contents/MacOS/Google\ Chrome ; exit;
ls
cd "/Applications/Google Chrome.app/Contents/MacOS/"
open .
cd ../
ls
cd ~
ls
cd Downloads
sudo mv chromedriver1 /usr/local/bin/
/Applications/Google Chrome.app/Contents/MacOS/Google Chrome
open /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
open "/Applications/Google Chrome.app/Contents/MacOS/Google Chrome"
cd "/Applications/Google Chrome.app/Contents/MacOS/Google Chrome"
cd "/Applications/Google Chrome.app/Contents/MacOS/"
open .
open "/Applications/Google Chrome.app/Contents/MacOS/Google Chrome.exe"
open "/Applications/Google Chrome.app/Contents/MacOS/Google Chrome.dmg"
echo $PATH
echo "${PATH//:/\n}"
sudo nano /etc/paths.
echo "${PATH//:/\n}"
open $PATH
sudo mv chromedriver1 /usr/local/bin/chromedriver1
sudo mv chromedriver1 /usr/local/bin/
sudo mv chromedriver1 /usr/bin/
ls
cd frontend
yarn start
brew install chromedrive
 brew install chrome-cli
brew install chromedriver
mkdir model middleware config\
\
touch config/database.js middleware/auth.js model/user.js
touch app.js
npm install cors mongoose express jsonwebtoken dotenv bcryptjs \

ls
cd backend
code .
yarn start
npm install @faker-js/faker --save-dev\

yarn start
heroku login
heroku git:remote -a buyhubhackathon
git add .
git commit -am "backend payment updates"
git push heroku master
heroku git:remote -a buyhubhackathon
cd backend 
heroku buildpacks
heroku config:add BUILDPACK_URL=git://github.com/heroku/heroku-buildpack-nodejs.git
heroku buildpacks
node --version
git push heroku main
git subtree push --prefix server backend master
git subtree push --prefix backend heroku master
git subtree push --prefix backend heroku master
cd ..
git subtree push --prefix backend heroku master
git push heroku main
git push heroku master
yarn add https://pay.seerbitapi.com/Delbert Sawayn StoreSun Nov 20 2022 20:57:49 GMT+0100 (West Africa Standard Time)
yarn add moment --save
npm i moment --save
npm i moment --save
yarn add moment --save
npm i
heroku logs --tail
heroku logs --tail -a
heroku logs --tail -a https://buyhubhackathon.herokuapp.com/
heroku logs --tail -a https://git.heroku.com/buyhubhackathon.git
heroku logs
heroku local web
heroku login
heroku create
git push heroku main
git push heroku main
git push heroku main
heroku restart
npm un @faker-js/faker
git push heroku main
yarn start
yarn add npm i @react-google-maps/api
yarn add i @react-google-maps/api
yarn add @react-google-maps/api
yarn start
cd ..
code .
ls
cd frontend
yarn start 
git branch
git pull origin dev
flutter run lib/main.dart
open -a Simulator.app
flutter run lib/main.dart
git reset --hard 402cf9227e9912e8fd9811e89b9ca767d31d57b2
git reset --hard 402cf9227e9912e8fd9811e89b9ca767d31d57b2
git push origin
fix_order_screen_freeze
open -a Simulator.app
open -a Simulator.app
git pull origin dev
git pull origin
git status
git merge --no-commit --no-ff
git merge --no-commit --no-ff dev
git diff --cached
git merge --abort
git pull origin dev
git diff --cached 
git checkout fix-disable-app-ratings-on-test-flavours
git pull origin dev
git checkout origin/dev dukka-app/pdf_generator/pubspec.lock
git checkout origin/dev /pdf_generator/pubspec.lock
git checkout origin/dev pdf_generator/pubspec.lock
cd frontend
yarn start
git pull origin dev
open -a simulator
open -a simulator
git pull origin dev
pod repo update
git pullorigine dev
git pull origin dev
spctl --add --label 'Approved' chromedriver
cd /usr/local/bin/
open .
ls
spctl --add --label 'Approved' /usr/local/bin/chromedriver
spctl --add --label 'Approved' /opt/homebrew/Caskroom/chromedriver/107.0.5304.62/chromedriver 
spctl --add --label 'Approved' /opt/homebrew/Caskroom/chromedriver/107.0.5304.62/chromedriver 
spctl --add --label 'Approved' '/opt/homebrew/Caskroom/chromedriver/107.0.5304.62/chromedriver '
cd /opt/homebrew/Caskroom/chromedriver/107.0.5304.62/chromedriver 
cd /opt/homebrew/Caskroom/chromedriver/107.0.5304.62/
xattr -d com.apple.quarantine chromedriver 
cd ~
cd /usr/local/bin/\
xattr -d com.apple.quarantine chromedriver 
ls
xattr -d com.apple.quarantine chromedriver
open -a simulator
/Applications/Google\ Chrome.app/Contents/MacOS/Google\ Chrome ; exit;
/usr/local/bin
ls
cd /usr/local/bin
ls
pwd
cd ~
ls
pwd
cd /Applications/Google Chrome.app/Contents/MacOS/
cd /Applications/Google Chrome.app/Contents/MacOS
ls
cd applications
ls
cd chrome
cd ~
open /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
open "/Applications/Google Chrome.app/Contents/MacOS/Google Chrome"
cd "/Applications/Google Chrome.app/Contents/MacOS/"
ls
open .
open "/Applications/Google\ Chrome.app/Contents/MacOS/Google\ Chrome "
source venv/bin/activate
sudo apt-get install python3-tk 
brew install python-tk
git checkout fix/order_bug_fix_nihal
git pull origin
cd des
ls
open .
source venv/bin/activate
python3 toms_python_utilities.py
pip list
python3 toms_python_utilities.py test
source /Users/tomideisawesome/Documents/GitHub/TomsWebScrapingCargo/venv/bin/activate
source /Users/tomideisawesome/Documents/GitHub/TomsWebScrapingCargo/venv/bin/activate
/Users/tomideisawesome/Library/CloudStorage/GoogleDrive-tommideadeoye@gmail.com/My\ Drive/APPLICATION\ BOX/Tomide\ Adeoye\ CV.pdf 
git pull origin dev
git reset --soft HEAD~1
source venv/bin/activate
ls
python3.9 -m pip install --user --upgrade pip
sudo python3.9 -m pip install --user virtualenv
python3.9 -m venv venv
git status
git checkout development
git log --oneline
git checkout analyst-dashboard
git merge development
conda activate
conda deactivate
git push origin analyst-dashboard
'''

# %%
commands2 = commands.splitlines()
len(commands)
# Out:
# 16161

# %%
# get unique commands
unique_commands = list(set(commands2))
# sort commands
# unique_commands.sort()


len(unique_commands)
for i in unique_commands:
    print(i)
# Out:
# sudo vi /etc/paths
# brew install cocoapods
# yarn add react-router && react-router-dom --save && yarn start
# git show HEAD~1:src/pages/analyst-dashboard/components/visualisations/chart-box.js
# heroku git:remote -a buyhubhackathon
# django-admin startproject trydjango .
# sudo kill -9 `sudo lsof -t -i:3000`
# source /Users/tomideisawesome/Documents/GitHub/TomsWebScrapingCargo/venv/bin/activate
# cd build
# git dd .
# yarn && yarn start:dev
# fix_order_screen_freeze
# sudo apt-get install python3-tk
# xattr -d com.apple.quarantine chromedriver
# git pull origin Test
# echo "${PATH//:/
# ls
# python3.9 -m venv venv
# git pull origin master
# git pull origin dev
# yarn add @types/react@17.0.0
# pip3 install dryscrape
# cd flutter
# flutter -h
# yarn remove axios
# heroku logs
# l
# yarn add file-saver
# yarn start dev
# npm init
# git pull origin development
# git branch
# yarn run predeploy
# python3 toms_python_utilities.py test
# nodemon index
# cd tryDjango
# ...
