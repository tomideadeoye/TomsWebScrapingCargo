# %% [markdown]
# #web scraping thingy

# %%
# ["type", "beds", "price", "location", "url", "aquisition", "contact", "duration", "furnished", "serviced", "imageurl"] //compare rent vs buy(month v day), should I buy/recommeded
# paginationSelector = soup.find('div', class_='pagination-area').nav.ul.findAll('li')[3].a['href']
# paginationSelector

'''
# return all div elements with a class attribute containing the text 'listing-col-':
for EachPart in soup.select('div[class*="listing-col-"]'):
    print EachPart.get_text()

'''
# Out:
# '\n# return all div elements with a class attribute containing the text \'listing-col-\':\nfor EachPart in soup.select(\'div[class*="listing-col-"]\'):\n    print EachPart.get_text()\n\n'

# %%
# !pip install selenium
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
from bs4.element import Comment
import re
import csv
import json
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import numpy as np

# %%
url = """

https://www.smartcontractresearch.org/latest


"""

# %%
def getPageData(url):
    driver = webdriver.Chrome('./chromedriver') 
    driver.get(url)
    time.sleep(10)     
    SCROLL_PAUSE_TIME = 10
    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
    # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    result = []
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')   
    scrf_summaries =  soup.find_all("tr")
    for post in scrf_summaries:
        if post.find('a', href=True):
            post_url = post.find('a', href=True)['href']
            if post_url.startswith('/'):
                post_url = 'https://www.smartcontractresearch.org' + post_url
            result.append(post_url)

    driver.close()
    return result

    
result =  getPageData(url)
# Out:
# /var/folders/yt/r5vqk9zd7f35c460q8mztp2w0000gn/T/ipykernel_7316/2375564607.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')

# %%
##UTILITIES

# WRITE DATA TO CSV FILE
# data is a list of lists

def createCsvFile(filename, rose):
    header =[ "title", "url", "category", "total_likes", "paper link", "tags", "comments"]
    with open(filename, 'w') as f:
        write = csv.writer(f)
        write.writerow(header)
        write.writerows(rose)

def unique(list1):
    unique_list = []
    for x in list1:
        if x not in unique_list:
            unique_list.append(x)
    return unique_list

# %%
result = unique(result)
len(result)
# Out:
# 120

# %%
finalPosts = []
header =[ "title", "url", "category", "total_likes", "paper link", "tags", "comments"]

def getPostComments(url):
    driver = webdriver.Chrome('./chromedriver') 
    result = []
    driver.get(url)
    time.sleep(10) 
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser') 
    # classes = soup.find_all(class_=True)
    category = soup.find(class_='category-name').text or ''
    tags = soup.find_all("a", class_='discourse-tag') or [""]
    tags = [tag.text for tag in tags]  
    tags = unique(tags)
    title= soup.find(class_='fancy-title').text.replace('\n', '')  or ''
    comments = soup.find_all("div", class_='cooked') or ['']
    comments = [comment.text for comment in comments]
    comments = [comment.replace('\n', '') for comment in comments] 
    total_likes = soup.find_all(class_='number')[3].text or ""
    links = soup.find_all('a', href=True) or [""]
    returnedLink = []
    for link in links:
        if "citation" in link['href']:
            index = links.index(link)
            returnedLink.append(links[index + 1]["href"]) 

    if len(comments) - 1 >= 10:
        finalPosts.append([ title, url, category, total_likes, unique(returnedLink), tags, comments])
        
    driver.close()

# %%
for post in result:
    # getPostComments(post[0])
    try:
        getPostComments(post)
        print(result.index(post), " of ", len(result))
        print(finalPosts[-1][0:2])
        
    except Exception as e:
        print("error on " + post)
        print(e)


createCsvFile('scrfabove10.csv', finalPosts)
# Out:
# /var/folders/yt/r5vqk9zd7f35c460q8mztp2w0000gn/T/ipykernel_7316/3266353824.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')
# 0  of  419
# ['                New to the forum? Start here              ', 'https://www.smartcontractresearch.org/t/new-to-the-forum-start-here/1162']
# 1  of  419
# ['                Research Summary: Towards A first step to understand flash loan and its application in Defi Ecosystem              ', 'https://www.smartcontractresearch.org/t/research-summary-towards-a-first-step-to-understand-flash-loan-and-its-application-in-defi-ecosystem/1551']
# 2  of  419
# ['                Research Summary: Towards A first step to understand flash loan and its application in Defi Ecosystem              ', 'https://www.smartcontractresearch.org/t/research-summary-towards-a-first-step-to-understand-flash-loan-and-its-application-in-defi-ecosystem/1551']
# 3  of  419
# ['                Research Summary: Towards A first step to understand flash loan and its application in Defi Ecosystem              ', 'https://www.smartcontractresearch.org/t/research-summary-towards-a-first-step-to-understand-flash-loan-and-its-application-in-defi-ecosystem/1551']
# 4  of  419
# ['                Research Summary: NFT Wash Trading: Quantifying Suspicious Behaviour in NFT Markets              ', 'https://www.smartcontractresearch.org/t/research-summary-nft-wash-trading-quantifying-suspicious-behaviour-in-nft-markets/1982']
# error on https://www.smartcontractresearch.org/t/reading-group-the-infinite-machine/1988
# 'str' object has no attribute 'text'
# 6  of  419
# ['                Research Summary: What is a DAO? Conceptual Foundations              ', 'https://www.smartcontractresearch.org/t/research-summary-what-is-a-dao-conceptual-foundations/1645']
# 7  of  419
# ['                Research Summary: What is a DAO? Conceptual Foundations              ', 'https://www.smartcontractresearch.org/t/research-summary-what-is-a-dao-conceptual-foundations/1645']
# 8  of  419
# ['                Research Summary: What is a DAO? Conceptual Foundations              ', 'https://www.smartcontractresearch.org/t/research-summary-what-is-a-dao-conceptual-foundations/1645']
# error on https://www.smartcontractresearch.org/t/research-summary-when-is-a-dao-decentralized/1903
# Message: disconnected: Unable to receive message from renderer
#   (Session info: chrome=105.0.5195.102)
# Stacktrace:
# 0   chromedriver                        0x00000001013848b8 chromedriver + 3885240
# 1   chromedriver                        0x0000000101314b1c chromedriver + 3427100
# 2   chromedriver                        0x0000000101006238 chromedriver + 221752
# 3   chromedriver                        0x0000000100ff486c chromedriver + 149612
# 4   chromedriver                        0x0000000100ff3fdc chromedriver + 147420
# 5   chromedriver                        0x000000010100cbb4 chromedriver + 248756
# 6   chromedriver                        0x0000000101060c74 chromedriver + 593012
# 7   chromedriver                        0x000000010102c54c chromedriver + 378188
# 8   chromedriver                        0x00000001013592c0 chromedriver + 3707584
# 9   chromedriver                        0x000000010135ce70 chromedriver + 3722864
# 10  chromedriver                        0x0000000101362200 chromedriver + 3744256
# 11  chromedriver                        0x000000010135d970 chromedriver + 3725680
# 12  chromedriver                        0x0000000101338db0 chromedriver + 3575216
# 13  chromedriver                        0x0000000101376b44 chromedriver + 3828548
# 14  chromedriver                        0x0000000101376cac chromedriver + 3828908
# 15  chromedriver                        0x000000010138b038 chromedriver + 3911736
# 16  libsystem_pthread.dylib             0x0000000183f79240 _pthread_start + 148
# 17  libsystem_pthread.dylib             0x0000000183f74024 thread_start + 8
#
# error on https://www.smartcontractresearch.org/t/research-pulse-81-09-05-2022/2008
# 'str' object has no attribute 'text'
# 11  of  419
# ['                Research Summary: Ethereum Name Service: the Good, the Bad, and the Ugly              ', 'https://www.smartcontractresearch.org/t/research-summary-ethereum-name-service-the-good-the-bad-and-the-ugly/1587']
# 12  of  419
# ['                SCRF Recommends              ', 'https://www.smartcontractresearch.org/t/scrf-recommends/1964']
# 13  of  419
# ['                SCRF Recommends              ', 'https://www.smartcontractresearch.org/t/scrf-recommends/1964']
# error on https://www.smartcontractresearch.org/t/implementing-sourcecred-on-the-forum/1295
# 'str' object has no attribute 'text'
# 15  of  419
# ['                Research Summary: On the Economic Design of Stablecoins              ', 'https://www.smartcontractresearch.org/t/research-summary-on-the-economic-design-of-stablecoins/817']
# 16  of  419
# ['                Research Summary: On the Economic Design of Stablecoins              ', 'https://www.smartcontractresearch.org/t/research-summary-on-the-economic-design-of-stablecoins/817']
# 17  of  419
# ['                Deep Diving into PRBMath, a Library for Advanced Fixed-Point Math              ', 'https://www.smartcontractresearch.org/t/deep-diving-into-prbmath-a-library-for-advanced-fixed-point-math/686']
# 18  of  419
# ['                Flying the SourceCred Plane              ', 'https://www.smartcontractresearch.org/t/flying-the-sourcecred-plane/1873']
# 19  of  419
# ['                Research Summary: Design and Implementation of Blockchain-based E-Voting              ', 'https://www.smartcontractresearch.org/t/research-summary-design-and-implementation-of-blockchain-based-e-voting/1885']
# 20  of  419
# ['                Research Summary: Design and Implementation of Blockchain-based E-Voting              ', 'https://www.smartcontractresearch.org/t/research-summary-design-and-implementation-of-blockchain-based-e-voting/1885']
# error on https://www.smartcontractresearch.org/t/scrf-contributor-recognition-and-rewards-initiative/860
# 'str' object has no attribute 'text'
# 22  of  419
# ['                Research Summary: Design and Implementation of Blockchain-based E-Voting              ', 'https://www.smartcontractresearch.org/t/research-summary-design-and-implementation-of-blockchain-based-e-voting/1885']
# 23  of  419
# ['                Research Summary: Design and Implementation of Blockchain-based E-Voting              ', 'https://www.smartcontractresearch.org/t/research-summary-design-and-implementation-of-blockchain-based-e-voting/1885']
# error on https://www.smartcontractresearch.org/t/discussion-post-on-pqc-quantum-vulnerabilities-of-blockchains/1854
# Message: unknown error: net::ERR_INTERNET_DISCONNECTED
#   (Session info: chrome=105.0.5195.102)
# Stacktrace:
# 0   chromedriver                        0x00000001045ac8b8 chromedriver + 3885240
# 1   chromedriver                        0x000000010453cb1c chromedriver + 3427100
# 2   chromedriver                        0x000000010422e238 chromedriver + 221752
# 3   chromedriver                        0x0000000104228cc4 chromedriver + 199876
# 4   chromedriver                        0x000000010421cf9c chromedriver + 151452
# 5   chromedriver                        0x000000010421dd3c chromedriver + 154940
# 6   chromedriver                        0x000000010421d1ec chromedriver + 152044
# 7   chromedriver                        0x000000010421c79c chromedriver + 149404
# 8   chromedriver                        0x000000010421b8b4 chromedriver + 145588
# 9   chromedriver                        0x000000010421bbb4 chromedriver + 146356
# 10  chromedriver                        0x000000010422fb7c chromedriver + 228220
# 11  chromedriver                        0x0000000104288f74 chromedriver + 593780
# 12  chromedriver                        0x0000000104288944 chromedriver + 592196
# 13  chromedriver                        0x000000010425454c chromedriver + 378188
# 14  chromedriver                        0x00000001045812c0 chromedriver + 3707584
# 15  chromedriver                        0x0000000104584e70 chromedriver + 3722864
# 16  chromedriver                        0x000000010458a200 chromedriver + 3744256
# 17  chromedriver                        0x0000000104585970 chromedriver + 3725680
# 18  chromedriver                        0x0000000104560db0 chromedriver + 3575216
# 19  chromedriver                        0x000000010459eb44 chromedriver + 3828548
# 20  chromedriver                        0x000000010459ecac chromedriver + 3828908
# 21  chromedriver                        0x00000001045b3038 chromedriver + 3911736
# 22  libsystem_pthread.dylib             0x0000000183f79240 _pthread_start + 148
# 23  libsystem_pthread.dylib             0x0000000183f74024 thread_start + 8
#
# error on https://www.smartcontractresearch.org/t/research-summary-flashsyn-flash-loan-attack-synthesis-via-counter-example-driven-approximation/1835
# Message: unknown error: net::ERR_INTERNET_DISCONNECTED
#   (Session info: chrome=105.0.5195.102)
# Stacktrace:
# 0   chromedriver                        0x00000
propertyForRent = pd.read_csv("ScrapedRentalDataSet.csv")

# %%
def abstractedReadToDataFrame(filename):
    df = pd.read_csv(filename)
    df = df.dropna()
    df = df.reset_index(drop=True)
    return df

df = abstractedReadToDataFrame("scrfabove10.csv")
df.sample(20)
df.sort_values(by=["total_likes"], ascending=False) 

# where title starts with "A"
# df[df['title'].str.startswith("R")].sort_values(by=["total_likes"], ascending=False)
df[df['title'].str.contains("r")]
# print title for all rows
df['title'].values

# strip whitespace from title
df['title'] = df['title'].str.strip()

# %%
# df['title'].values
# df['title'].str.contains("research")
# convert title to string
# df['title'] = df['title'].astype(str)
from tabnanny import check


summaries_only = df[df['url'].str.contains("summary")]  

sorted_summaries = summaries_only.sort_values(by=["total_likes"], ascending=False)
sorted_summaries
whereTagsShort = sorted_summaries[sorted_summaries['tags'].str.len() == 2]
whereTagsShort
# Out:
# Empty DataFrame
# Columns: [title, url, category, total_likes, paper link, tags, comments]
# Index: []

# %%
from ast import literal_eval

try:
    sorted_summaries['tags'] = sorted_summaries['tags'].apply(literal_eval)
except:
    pass

# %%
sorted_summaries['tags'].iloc[0]
# Out:
# ['scalability', 'iot', 'summary']

# %%
whereTagsShort = sorted_summaries[sorted_summaries['tags'].str.len() < 3 ]
whereTagsShort = whereTagsShort[whereTagsShort["comments"].str.len() > 10]
whereTagsShort["title"]
for i in whereTagsShort["title"]:
    print(i.replace('Research Summary:', '').strip())
# Out:
# Leveraging Blockchain for Greater Accessibility of Machine Learning Models
# SoK: Applying Blockchain Technology in Industrial Internet of Things
# On the Economic Design of Stablecoins
# Ethereum Name Service: the Good, the Bad, and the Ugly
# Research Summary - What is in Your Wallet? Privacy and Security Issues in Web 3.0
# Using Distributed Ledger Technologies to Improve and Maximise the Collection of Property Taxes
# Towards A first step to understand flash loan and its application in Defi Ecosystem

# %%
# print title and url for all rows
for i in range(len(whereTagsShort)):
    print(whereTagsShort["title"].iloc[i].replace('Research Summary:', '').strip(), whereTagsShort["url"].iloc[i])
# Out:
# Leveraging Blockchain for Greater Accessibility of Machine Learning Models https://www.smartcontractresearch.org/t/research-summary-leveraging-blockchain-for-greater-accessibility-of-machine-learning-models/808
# SoK: Applying Blockchain Technology in Industrial Internet of Things https://www.smartcontractresearch.org/t/research-summary-sok-applying-blockchain-technology-in-industrial-internet-of-things/866
# On the Economic Design of Stablecoins https://www.smartcontractresearch.org/t/research-summary-on-the-economic-design-of-stablecoins/817
# Ethereum Name Service: the Good, the Bad, and the Ugly https://www.smartcontractresearch.org/t/research-summary-ethereum-name-service-the-good-the-bad-and-the-ugly/1587
# Research Summary - What is in Your Wallet? Privacy and Security Issues in Web 3.0 https://www.smartcontractresearch.org/t/research-summary-what-is-in-your-wallet-privacy-and-security-issues-in-web-3-0/1225
# Using Distributed Ledger Technologies to Improve and Maximise the Collection of Property Taxes https://www.smartcontractresearch.org/t/research-summary-using-distributed-ledger-technologies-to-improve-and-maximise-the-collection-of-property-taxes/1176
# Towards A first step to understand flash loan and its application in Defi Ecosystem https://www.smartcontractresearch.org/t/research-summary-towards-a-first-step-to-understand-flash-loan-and-its-application-in-defi-ecosystem/1551
